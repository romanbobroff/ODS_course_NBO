# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import warnings

from lib.pipelines import boosting_pipeline

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Category_id

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_cat, durs, test = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'bm25_rnk', 'toppop_rnk', 'apriori_rnk', 'bm25_score', 'toppop_score',
#        'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.450664554176569,
#     "precision@05": 0.26604172167942963,
#     "precision@10": 0.2048895343719743,
#     "precision@20": 0.15704383416952736,
#     "recall@01": 0.031513196142105425,
#     "recall@05": 0.08942740459100194,
#     "recall@10": 0.13269096317783155,
#     "recall@20": 0.19370235836706162,
#     "user_hitted@01": 0.15491594049819557,
#     "user_hitted@05": 0.3376463339494763,
#     "user_hitted@10": 0.4247865504797113,
#     "user_hitted@20": 0.5074377255523281
# }
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# toppop metrics:
# {
#     "precision@01": 0.27277528386585687,
#     "precision@05": 0.28819646157908635,
#     "precision@10": 0.22222075521520993,
#     "precision@20": 0.17102587800369687,
#     "recall@01": 0.0109727458346157,
#     "recall@05": 0.06332079881224069,
#     "recall@10": 0.11906548347031141,
#     "recall@20": 0.18539419213445277,
#     "user_hitted@01": 0.031379279992958364,
#     "user_hitted@05": 0.2720271102895872,
#     "user_hitted@10": 0.42588680573893145,
#     "user_hitted@20": 0.5270662793768154
# }
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# apriori metrics:
# {
#     "precision@01": 0.06293460082739195,
#     "precision@05": 0.12445207288090836,
#     "precision@10": 0.11952292931960215,
#     "precision@20": 0.08964879852125693,
#     "recall@01": 0.0043559849180269325,
#     "recall@05": 0.06756276402475885,
#     "recall@10": 0.12015909890036848,
#     "recall@20": 0.17264811305744185,
#     "user_hitted@01": 0.03063110641668867,
#     "user_hitted@05": 0.19192852741836106,
#     "user_hitted@10": 0.2938121644221459,
#     "user_hitted@20": 0.4005369245664994
# }
# {'MAE': Timedelta('88 days 04:18:26.325307963')}
# Boosting metrics:
# {
#     "precision@01": 0.6632778804682686,
#     "precision@05": 0.3956077810051932,
#     "precision@10": 0.2971437373470645,
#     "precision@20": 0.2128377783645806,
#     "recall@01": 0.047390508610395024,
#     "recall@05": 0.14105732882673455,
#     "recall@10": 0.20754277662433981,
#     "recall@20": 0.2877020991564737,
#     "user_hitted@01": 0.2065399172608045,
#     "user_hitted@05": 0.4472757679781709,
#     "user_hitted@10": 0.5607781005193205,
#     "user_hitted@20": 0.6565883284922102
# }
# {'MAE': Timedelta('88 days 20:12:22.883907661')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_cat, durs, test = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 21 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'bm25_rnk', 'toppop_rnk', 'usertoppop_rnk', 'apriori_rnk', 'bm25_score',
#        'toppop_score', 'usertoppop_score', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.450664554176569,
#     "precision@05": 0.26604172167942963,
#     "precision@10": 0.2048895343719743,
#     "precision@20": 0.15704383416952736,
#     "recall@01": 0.031513196142105425,
#     "recall@05": 0.08942740459100194,
#     "recall@10": 0.13269096317783155,
#     "recall@20": 0.19370235836706162,
#     "user_hitted@01": 0.15491594049819557,
#     "user_hitted@05": 0.3376463339494763,
#     "user_hitted@10": 0.4247865504797113,
#     "user_hitted@20": 0.5074377255523281
# }
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# toppop metrics:
# {
#     "precision@01": 0.27277528386585687,
#     "precision@05": 0.28819646157908635,
#     "precision@10": 0.22222075521520993,
#     "precision@20": 0.17102587800369687,
#     "recall@01": 0.0109727458346157,
#     "recall@05": 0.06332079881224069,
#     "recall@10": 0.11906548347031141,
#     "recall@20": 0.18539419213445277,
#     "user_hitted@01": 0.031379279992958364,
#     "user_hitted@05": 0.2720271102895872,
#     "user_hitted@10": 0.42588680573893145,
#     "user_hitted@20": 0.5270662793768154
# }
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# usertoppop metrics:
# {
#     "precision@01": 0.5521080890766658,
#     "precision@05": 0.42221635419417297,
#     "precision@10": 0.36427691224364056,
#     "precision@20": 0.2334367573277,
#     "recall@01": 0.03982316796587005,
#     "recall@05": 0.14560823501735157,
#     "recall@10": 0.22734643232134008,
#     "recall@20": 0.26492564586507394,
#     "user_hitted@01": 0.1542557873426635,
#     "user_hitted@05": 0.4199894375495115,
#     "user_hitted@10": 0.4983276120059854,
#     "user_hitted@20": 0.5103864096470381
# }
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# apriori metrics:
# {
#     "precision@01": 0.06293460082739195,
#     "precision@05": 0.12445207288090836,
#     "precision@10": 0.11952292931960215,
#     "precision@20": 0.08964879852125693,
#     "recall@01": 0.0043559849180269325,
#     "recall@05": 0.06756276402475885,
#     "recall@10": 0.12015909890036848,
#     "recall@20": 0.17264811305744185,
#     "user_hitted@01": 0.03063110641668867,
#     "user_hitted@05": 0.19192852741836106,
#     "user_hitted@10": 0.2938121644221459,
#     "user_hitted@20": 0.4005369245664994
# }
# {'MAE': Timedelta('88 days 04:18:26.325307963')}
# Boosting metrics:
# {
#     "precision@01": 0.6701434732858023,
#     "precision@05": 0.4027814452953085,
#     "precision@10": 0.30455505677317135,
#     "precision@20": 0.21927207112049996,
#     "recall@01": 0.04929204277590488,
#     "recall@05": 0.14393315902045775,
#     "recall@10": 0.21382533122790995,
#     "recall@20": 0.2997725267672343,
#     "user_hitted@01": 0.2072440806267054,
#     "user_hitted@05": 0.4550215650030807,
#     "user_hitted@10": 0.5693600915412376,
#     "user_hitted@20": 0.6679869729777308
# }
# {'MAE': Timedelta('89 days 06:13:34.449127031')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    'markov',
    'toppop',
    'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_cat, durs, test = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 23 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'bm25_rnk', 'markov_rnk', 'toppop_rnk', 'usertoppop_rnk', 'apriori_rnk',
#        'bm25_score', 'markov_score', 'toppop_score', 'usertoppop_score',
#        'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.450664554176569,
#     "precision@05": 0.26604172167942963,
#     "precision@10": 0.2048895343719743,
#     "precision@20": 0.15704383416952736,
#     "recall@01": 0.031513196142105425,
#     "recall@05": 0.08942740459100194,
#     "recall@10": 0.13269096317783155,
#     "recall@20": 0.19370235836706162,
#     "user_hitted@01": 0.15491594049819557,
#     "user_hitted@05": 0.3376463339494763,
#     "user_hitted@10": 0.4247865504797113,
#     "user_hitted@20": 0.5074377255523281
# }
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# markov metrics:
# {
#     "precision@01": 0.15297949124196814,
#     "precision@05": 0.09876771410967343,
#     "precision@10": 0.08634363172255964,
#     "precision@20": 0.07289191092333422,
#     "recall@01": 0.014248590167349168,
#     "recall@05": 0.038979464121862165,
#     "recall@10": 0.06265008719557559,
#     "recall@20": 0.10024013638128591,
#     "user_hitted@01": 0.08709620631986621,
#     "user_hitted@05": 0.21459378575829594,
#     "user_hitted@10": 0.29838922630050174,
#     "user_hitted@20": 0.38909426987060997
# }
# {'MAE': Timedelta('86 days 21:22:53.677803328')}
# toppop metrics:
# {
#     "precision@01": 0.27277528386585687,
#     "precision@05": 0.28819646157908635,
#     "precision@10": 0.22222075521520993,
#     "precision@20": 0.17102587800369687,
#     "recall@01": 0.0109727458346157,
#     "recall@05": 0.06332079881224069,
#     "recall@10": 0.11906548347031141,
#     "recall@20": 0.18539419213445277,
#     "user_hitted@01": 0.031379279992958364,
#     "user_hitted@05": 0.2720271102895872,
#     "user_hitted@10": 0.42588680573893145,
#     "user_hitted@20": 0.5270662793768154
# }
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# usertoppop metrics:
# {
#     "precision@01": 0.5521080890766658,
#     "precision@05": 0.42221635419417297,
#     "precision@10": 0.36427691224364056,
#     "precision@20": 0.2334367573277,
#     "recall@01": 0.03982316796587005,
#     "recall@05": 0.14560823501735157,
#     "recall@10": 0.22734643232134008,
#     "recall@20": 0.26492564586507394,
#     "user_hitted@01": 0.1542557873426635,
#     "user_hitted@05": 0.4199894375495115,
#     "user_hitted@10": 0.4983276120059854,
#     "user_hitted@20": 0.5103864096470381
# }
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# apriori metrics:
# {
#     "precision@01": 0.06293460082739195,
#     "precision@05": 0.12445207288090836,
#     "precision@10": 0.11952292931960215,
#     "precision@20": 0.08964879852125693,
#     "recall@01": 0.0043559849180269325,
#     "recall@05": 0.06756276402475885,
#     "recall@10": 0.12015909890036848,
#     "recall@20": 0.17264811305744185,
#     "user_hitted@01": 0.03063110641668867,
#     "user_hitted@05": 0.19192852741836106,
#     "user_hitted@10": 0.2938121644221459,
#     "user_hitted@20": 0.4005369245664994
# }
# {'MAE': Timedelta('88 days 04:18:26.325307963')}
# Boosting metrics:
# {
#     "precision@01": 0.6650822990933897,
#     "precision@05": 0.4036968576709796,
#     "precision@10": 0.30489833641404807,
#     "precision@20": 0.21945691400404893,
#     "recall@01": 0.05047156229496251,
#     "recall@05": 0.14858614799210562,
#     "recall@10": 0.21639222509963815,
#     "recall@20": 0.30120322975955016,
#     "user_hitted@01": 0.21300941818501892,
#     "user_hitted@05": 0.4649678725464308,
#     "user_hitted@10": 0.5764457354106153,
#     "user_hitted@20": 0.670671595810228
# }
# {'MAE': Timedelta('89 days 10:07:16.032821976')}

# %% [markdown]
# ### Item_id

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item, durs, test = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 21 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'tfidf_rnk', 'apriori_rnk',
#        'tfidf_score', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.04854326203679254,
#     "precision@05": 0.032101047443006785,
#     "precision@10": 0.026925446703635246,
#     "precision@20": 0.02174324443270839,
#     "recall@01": 0.006983712078973833,
#     "recall@05": 0.018679016767909295,
#     "recall@10": 0.026707643211061866,
#     "recall@20": 0.03729350317623011,
#     "user_hitted@01": 0.038861015755655315,
#     "user_hitted@05": 0.09422586039961271,
#     "user_hitted@10": 0.134451192676701,
#     "user_hitted@20": 0.18466684270750813
# }
# {'MAE': Timedelta('78 days 06:13:29.018595586')}
# apriori metrics:
# {
#     "precision@01": 0.006689551976058445,
#     "precision@05": 0.008511574685326997,
#     "precision@10": 0.007384913299885574,
#     "precision@20": 0.0057191268374262826,
#     "recall@01": 0.0002959972129945784,
#     "recall@05": 0.0027609084240043406,
#     "recall@10": 0.004304026576115279,
#     "recall@20": 0.005703405305306105,
#     "user_hitted@01": 0.005677317137575918,
#     "user_hitted@05": 0.020684798873338614,
#     "user_hitted@10": 0.030411055364844643,
#     "user_hitted@20": 0.03978523017340023
# }
# {'MAE': Timedelta('64 days 02:56:37.851562500')}
# Boosting metrics:
# {
#     "precision@01": 0.07935040929495643,
#     "precision@05": 0.0501364316521433,
#     "precision@10": 0.03783117683302526,
#     "precision@20": 0.02766921925886806,
#     "recall@01": 0.00979074270390488,
#     "recall@05": 0.026320582190886763,
#     "recall@10": 0.03544831296659903,
#     "recall@20": 0.04655451059848065,
#     "user_hitted@01": 0.06368277440366164,
#     "user_hitted@05": 0.1469941026318106,
#     "user_hitted@10": 0.18620720007041633,
#     "user_hitted@20": 0.22678461403045508
# }
# {'MAE': Timedelta('79 days 08:16:05.527212641')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    'apriori_lastnext',
]
predicted_item, durs, test = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 21 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'apriori_rnk',
#        'apriori_lastnext_rnk', 'apriori_score', 'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {
#     "precision@01": 0.006689551976058445,
#     "precision@05": 0.008511574685326997,
#     "precision@10": 0.007384913299885574,
#     "precision@20": 0.0057191268374262826,
#     "recall@01": 0.0002959972129945784,
#     "recall@05": 0.0027609084240043406,
#     "recall@10": 0.004304026576115279,
#     "recall@20": 0.005703405305306105,
#     "user_hitted@01": 0.005677317137575918,
#     "user_hitted@05": 0.020684798873338614,
#     "user_hitted@10": 0.030411055364844643,
#     "user_hitted@20": 0.03978523017340023
# }
# {'MAE': Timedelta('64 days 02:56:37.851562500')}
# apriori_lastnext metrics:
# {
#     "precision@01": 0.028826687791567645,
#     "precision@05": 0.09653199542293812,
#     "precision@10": 0.07900272863304288,
#     "precision@20": 0.057299093389666406,
#     "recall@01": 0.0031636736340000635,
#     "recall@05": 0.0570440399149354,
#     "recall@10": 0.087110164291645,
#     "recall@20": 0.11739683609055,
#     "user_hitted@01": 0.027726432532347505,
#     "user_hitted@05": 0.20671595810227972,
#     "user_hitted@10": 0.2903353578030103,
#     "user_hitted@20": 0.36990581814981077
# }
# {'MAE': Timedelta('78 days 04:43:59.119869218')}
# Boosting metrics:
# {
#     "precision@01": 0.11667106768770355,
#     "precision@05": 0.10628465804066543,
#     "precision@10": 0.08027022269166446,
#     "precision@20": 0.057602763841211164,
#     "recall@01": 0.014010170874035643,
#     "recall@05": 0.06347024940404067,
#     "recall@10": 0.08966986480985799,
#     "recall@20": 0.11929244970011604,
#     "user_hitted@01": 0.10663673972361588,
#     "user_hitted@05": 0.24588504533051667,
#     "user_hitted@10": 0.31467300413695976,
#     "user_hitted@20": 0.3858815245136872
# }
# {'MAE': Timedelta('74 days 16:29:59.665986268')}

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item, durs, test = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 23 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'tfidf_rnk', 'usertoppop_rnk',
#        'apriori_rnk', 'tfidf_score', 'usertoppop_score', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.04854326203679254,
#     "precision@05": 0.032101047443006785,
#     "precision@10": 0.026925446703635246,
#     "precision@20": 0.02174324443270839,
#     "recall@01": 0.006983712078973833,
#     "recall@05": 0.018679016767909295,
#     "recall@10": 0.026707643211061866,
#     "recall@20": 0.03729350317623011,
#     "user_hitted@01": 0.038861015755655315,
#     "user_hitted@05": 0.09422586039961271,
#     "user_hitted@10": 0.134451192676701,
#     "user_hitted@20": 0.18466684270750813
# }
# {'MAE': Timedelta('78 days 06:13:29.018595586')}
# usertoppop metrics:
# {
#     "precision@01": 0.17300413695977468,
#     "precision@05": 0.18258075873602678,
#     "precision@10": 0.11734882492738316,
#     "precision@20": 0.06403045506557521,
#     "recall@01": 0.02225107275119123,
#     "recall@05": 0.06728594277385949,
#     "recall@10": 0.07470689119495301,
#     "recall@20": 0.07594869798443386,
#     "user_hitted@01": 0.10892527066279377,
#     "user_hitted@05": 0.2969368893583311,
#     "user_hitted@10": 0.3090837074201215,
#     "user_hitted@20": 0.3094357891030719
# }
# {'MAE': Timedelta('69 days 09:10:20.210344331')}
# apriori metrics:
# {
#     "precision@01": 0.006689551976058445,
#     "precision@05": 0.008511574685326997,
#     "precision@10": 0.007384913299885574,
#     "precision@20": 0.0057191268374262826,
#     "recall@01": 0.0002959972129945784,
#     "recall@05": 0.0027609084240043406,
#     "recall@10": 0.004304026576115279,
#     "recall@20": 0.005703405305306105,
#     "user_hitted@01": 0.005677317137575918,
#     "user_hitted@05": 0.020684798873338614,
#     "user_hitted@10": 0.030411055364844643,
#     "user_hitted@20": 0.03978523017340023
# }
# {'MAE': Timedelta('64 days 02:56:37.851562500')}
# Boosting metrics:
# {
#     "precision@01": 0.08876859431388082,
#     "precision@05": 0.05532963647566236,
#     "precision@10": 0.04158524777748438,
#     "precision@20": 0.030283425754775113,
#     "recall@01": 0.010970744283319442,
#     "recall@05": 0.02821318075394366,
#     "recall@10": 0.03832180550031896,
#     "recall@20": 0.05067213524776862,
#     "user_hitted@01": 0.07081242848340816,
#     "user_hitted@05": 0.15887685943138807,
#     "user_hitted@10": 0.20139072264765426,
#     "user_hitted@20": 0.24742540269342486
# }
# {'MAE': Timedelta('79 days 11:52:01.229489488')}
