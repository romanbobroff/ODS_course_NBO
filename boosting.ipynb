# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import warnings

from lib.pipelines import boosting_pipeline

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Таргет - item_id

# %% [markdown]
# ### 2 months

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'toppop_rnk', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {
#     "precision@01": 0.052020068655928176,
#     "precision@05": 0.02793768154211777,
#     "precision@10": 0.021639820438341697,
#     "precision@20": 0.020246897280169,
#     "recall@01": 0.004730452305995105,
#     "recall@05": 0.012131605182939896,
#     "recall@10": 0.017700378257942972,
#     "recall@20": 0.028117394468921093,
#     "user_hitted@01": 0.037716750286066365,
#     "user_hitted@05": 0.0878883901065047,
#     "user_hitted@10": 0.13141448816125342,
#     "user_hitted@20": 0.20935657072440805
# }
# {'MAE': Timedelta('82 days 17:35:20.577189168')}
# Boosting metrics:
# {
#     "precision@01": 0.08529178769474519,
#     "precision@05": 0.04850805386849749,
#     "precision@10": 0.036458058269518534,
#     "precision@20": 0.026131062406478302,
#     "recall@01": 0.010546755476434484,
#     "recall@05": 0.022455193105706345,
#     "recall@10": 0.029264564964121737,
#     "recall@20": 0.03847283055641976,
#     "user_hitted@01": 0.07156060205967785,
#     "user_hitted@05": 0.15302350145233695,
#     "user_hitted@10": 0.19355690520200686,
#     "user_hitted@20": 0.2395915852477775
# }
# {'MAE': Timedelta('82 days 17:35:20.577189168')}
# CPU times: user 55min 34s, sys: 2min 27s, total: 58min 2s
# Wall time: 3min 20s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'usertoppop_rnk',
#        'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {
#     "precision@01": 0.17300413695977468,
#     "precision@05": 0.18258075873602678,
#     "precision@10": 0.11734882492738316,
#     "precision@20": 0.06403045506557521,
#     "recall@01": 0.02225107275119123,
#     "recall@05": 0.06728594277385949,
#     "recall@10": 0.07470689119495301,
#     "recall@20": 0.07594869798443386,
#     "user_hitted@01": 0.10892527066279377,
#     "user_hitted@05": 0.2969368893583311,
#     "user_hitted@10": 0.3090837074201215,
#     "user_hitted@20": 0.3094357891030719
# }
# {'MAE': Timedelta('69 days 09:10:20.210344331')}
# Boosting metrics:
# {
#     "precision@01": 0.08106680749933985,
#     "precision@05": 0.04797112930199807,
#     "precision@10": 0.035093741748085557,
#     "precision@20": 0.024874570900448905,
#     "recall@01": 0.010751731726123944,
#     "recall@05": 0.02517446792752954,
#     "recall@10": 0.033291604375749496,
#     "recall@20": 0.042262593247691195,
#     "user_hitted@01": 0.06346272335181762,
#     "user_hitted@05": 0.13973241792095767,
#     "user_hitted@10": 0.1763929231581727,
#     "user_hitted@20": 0.21494586744124636
# }
# {'MAE': Timedelta('69 days 09:10:20.210344331')}
# CPU times: user 4h 2min 8s, sys: 7min 9s, total: 4h 9min 18s
# Wall time: 13min 30s

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'tfidf_rnk', 'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.04854326203679254,
#     "precision@05": 0.032101047443006785,
#     "precision@10": 0.026925446703635246,
#     "precision@20": 0.02174324443270839,
#     "recall@01": 0.006983712078973833,
#     "recall@05": 0.018679016767909295,
#     "recall@10": 0.026707643211061866,
#     "recall@20": 0.03729350317623011,
#     "user_hitted@01": 0.038861015755655315,
#     "user_hitted@05": 0.09422586039961271,
#     "user_hitted@10": 0.134451192676701,
#     "user_hitted@20": 0.18466684270750813
# }
# {'MAE': Timedelta('78 days 06:13:29.018595586')}
# Boosting metrics:
# {
#     "precision@01": 0.07807411319426107,
#     "precision@05": 0.04717014347328581,
#     "precision@10": 0.03548543262036793,
#     "precision@20": 0.02623008537980812,
#     "recall@01": 0.010184041418256417,
#     "recall@05": 0.02528131752599534,
#     "recall@10": 0.03388050973143564,
#     "recall@20": 0.04458664807678656,
#     "user_hitted@01": 0.06231845788222868,
#     "user_hitted@05": 0.1400404893935393,
#     "user_hitted@10": 0.17656896399964792,
#     "user_hitted@20": 0.2174544494322683
# }
# {'MAE': Timedelta('78 days 06:13:29.018595586')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'bm25_rnk', 'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.038332893231229646,
#     "precision@05": 0.02449608309127718,
#     "precision@10": 0.019910219170847634,
#     "precision@20": 0.015793063990845877,
#     "recall@01": 0.006539832329996938,
#     "recall@05": 0.01670276020492628,
#     "recall@10": 0.024089110042406377,
#     "recall@20": 0.03320416441038049,
#     "user_hitted@01": 0.03133526978258956,
#     "user_hitted@05": 0.07424522489217499,
#     "user_hitted@10": 0.10553648446439574,
#     "user_hitted@20": 0.1479183170495555
# }
# {'MAE': Timedelta('77 days 21:22:08.606436857')}
# Boosting metrics:
# {
#     "precision@01": 0.05958982483936273,
#     "precision@05": 0.03583311328228149,
#     "precision@10": 0.026599771146906086,
#     "precision@20": 0.019012410879324003,
#     "recall@01": 0.009094409426272371,
#     "recall@05": 0.02227113759322442,
#     "recall@10": 0.03002026854594226,
#     "recall@20": 0.03854298184182445,
#     "user_hitted@01": 0.04779508846052284,
#     "user_hitted@05": 0.10738491329988557,
#     "user_hitted@10": 0.1402165302350145,
#     "user_hitted@20": 0.17269606548719302
# }
# {'MAE': Timedelta('77 days 21:22:08.606436857')}

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'cosine_rnk', 'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {
#     "precision@01": 0.04577061878355779,
#     "precision@05": 0.031203239151483143,
#     "precision@10": 0.024808555584895697,
#     "precision@20": 0.020022445207288093,
#     "recall@01": 0.007197878884606339,
#     "recall@05": 0.017878622032876285,
#     "recall@10": 0.0246082056328666,
#     "recall@20": 0.033958830244659975,
#     "user_hitted@01": 0.03736466860311592,
#     "user_hitted@05": 0.09413783997887509,
#     "user_hitted@10": 0.12758559985916731,
#     "user_hitted@20": 0.17384033095678197
# }
# {'MAE': Timedelta('76 days 23:23:08.518857266')}
# Boosting metrics:
# {
#     "precision@01": 0.07657776604172167,
#     "precision@05": 0.04622832497139337,
#     "precision@10": 0.034556817181586125,
#     "precision@20": 0.02468972801689992,
#     "recall@01": 0.010526579685522912,
#     "recall@05": 0.024293772072232954,
#     "recall@10": 0.032460727711770575,
#     "recall@20": 0.04139705809144092,
#     "user_hitted@01": 0.0609101311504269,
#     "user_hitted@05": 0.13471525393891381,
#     "user_hitted@10": 0.1718158612798169,
#     "user_hitted@20": 0.20640788662969808
# }
# {'MAE': Timedelta('76 days 23:23:08.518857266')}
# CPU times: user 59min 58s, sys: 2min 42s, total: 1h 2min 40s
# Wall time: 5min 2s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'markov_rnk', 'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {
#     "precision@01": 0.006337470293108001,
#     "precision@05": 0.006390282545550569,
#     "precision@10": 0.005263621160109145,
#     "precision@20": 0.004024733738227269,
#     "recall@01": 0.000535708870908151,
#     "recall@05": 0.0025018226771402036,
#     "recall@10": 0.004281734616768277,
#     "recall@20": 0.006389964512905145,
#     "user_hitted@01": 0.0050611741924126395,
#     "user_hitted@05": 0.023633482968048587,
#     "user_hitted@10": 0.03767274007569756,
#     "user_hitted@20": 0.05320834433588593
# }
# {'MAE': Timedelta('78 days 15:02:22.033932336')}
# Boosting metrics:
# {
#     "precision@01": 0.02222515623624681,
#     "precision@05": 0.012199630314232901,
#     "precision@10": 0.007957046034680046,
#     "precision@20": 0.004860927735234575,
#     "recall@01": 0.0023802313414585654,
#     "recall@05": 0.004900533150273957,
#     "recall@10": 0.006091706346415728,
#     "recall@20": 0.007477894907225096,
#     "user_hitted@01": 0.01685591057125253,
#     "user_hitted@05": 0.03947715870081859,
#     "user_hitted@10": 0.0490273743508494,
#     "user_hitted@20": 0.05796144705571692
# }
# {'MAE': Timedelta('78 days 15:02:22.033932336')}
# CPU times: user 33min 52s, sys: 9min 31s, total: 43min 24s
# Wall time: 14min 49s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'apriori_rnk', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {
#     "precision@01": 0.006689551976058445,
#     "precision@05": 0.008511574685326997,
#     "precision@10": 0.007384913299885574,
#     "precision@20": 0.0057191268374262826,
#     "recall@01": 0.0002959972129945784,
#     "recall@05": 0.0027609084240043406,
#     "recall@10": 0.004304026576115279,
#     "recall@20": 0.005703405305306105,
#     "user_hitted@01": 0.005677317137575918,
#     "user_hitted@05": 0.020684798873338614,
#     "user_hitted@10": 0.030411055364844643,
#     "user_hitted@20": 0.03978523017340023
# }
# {'MAE': Timedelta('64 days 02:56:37.851562500')}
# Boosting metrics:
# {
#     "precision@01": 0.02262124812956606,
#     "precision@05": 0.013872018308247516,
#     "precision@10": 0.009559017692104568,
#     "precision@20": 0.006590529002728633,
#     "recall@01": 0.0010724290397827949,
#     "recall@05": 0.003382475218760838,
#     "recall@10": 0.00447032514730044,
#     "recall@20": 0.0058018837242259655,
#     "user_hitted@01": 0.01725200246457178,
#     "user_hitted@05": 0.0324355250418097,
#     "user_hitted@10": 0.039345128069712174,
#     "user_hitted@20": 0.04603468004577062
# }
# {'MAE': Timedelta('64 days 02:56:37.851562500')}
# CPU times: user 9min 37s, sys: 37.7 s, total: 10min 15s
# Wall time: 1min 4s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'apriori_lastnext_rnk',
#        'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {
#     "precision@01": 0.028826687791567645,
#     "precision@05": 0.09653199542293812,
#     "precision@10": 0.07900272863304288,
#     "precision@20": 0.057299093389666406,
#     "recall@01": 0.0031636736340000635,
#     "recall@05": 0.0570440399149354,
#     "recall@10": 0.087110164291645,
#     "recall@20": 0.11739683609055,
#     "user_hitted@01": 0.027726432532347505,
#     "user_hitted@05": 0.20671595810227972,
#     "user_hitted@10": 0.2903353578030103,
#     "user_hitted@20": 0.36990581814981077
# }
# {'MAE': Timedelta('78 days 04:43:59.119869218')}
# Boosting metrics:
# {
#     "precision@01": 0.11209400580934777,
#     "precision@05": 0.11019276472141537,
#     "precision@10": 0.08323651087052197,
#     "precision@20": 0.05901769210456826,
#     "recall@01": 0.013287729750406025,
#     "recall@05": 0.06519050180570547,
#     "recall@10": 0.09207530293514363,
#     "recall@20": 0.12156779450280064,
#     "user_hitted@01": 0.10690080098582871,
#     "user_hitted@05": 0.2538949036176393,
#     "user_hitted@10": 0.32321098494850803,
#     "user_hitted@20": 0.392483056069008
# }
# {'MAE': Timedelta('78 days 04:43:59.119869218')}
# CPU times: user 9min 4s, sys: 41.6 s, total: 9min 45s
# Wall time: 1min 16s

# %% [markdown]
# ### 6 months

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'toppop_rnk', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {
#     "precision@01": 0.07449225013361839,
#     "precision@05": 0.047724033493675384,
#     "precision@10": 0.033591662212720474,
#     "precision@20": 0.027222519151968647,
#     "recall@01": 0.004301904297939997,
#     "recall@05": 0.013929633360564657,
#     "recall@10": 0.02005287407265937,
#     "recall@20": 0.02734711197228071,
#     "user_hitted@01": 0.04623196151790487,
#     "user_hitted@05": 0.12758328879387137,
#     "user_hitted@10": 0.16455104222340994,
#     "user_hitted@20": 0.22969000534473544
# }
# {'MAE': Timedelta('144 days 11:32:17.294155012')}
# Boosting metrics:
# {
#     "precision@01": 0.13493230001781578,
#     "precision@05": 0.07695528238018884,
#     "precision@10": 0.056656422590415104,
#     "precision@20": 0.04109767504008552,
#     "recall@01": 0.012260404749767648,
#     "recall@05": 0.0256986275107659,
#     "recall@10": 0.0330955392456975,
#     "recall@20": 0.041975979077219984,
#     "user_hitted@01": 0.0997906645287725,
#     "user_hitted@05": 0.21236415464101194,
#     "user_hitted@10": 0.26004364867272406,
#     "user_hitted@20": 0.3092152146802067
# }
# {'MAE': Timedelta('144 days 11:32:17.294155014')}
# CPU times: user 59min 52s, sys: 2min 39s, total: 1h 2min 31s
# Wall time: 3min 45s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'usertoppop_rnk',
#        'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {
#     "precision@01": 0.19151968644218778,
#     "precision@05": 0.22366827008729737,
#     "precision@10": 0.14471093889185818,
#     "precision@20": 0.07862662569036168,
#     "recall@01": 0.013556174557401511,
#     "recall@05": 0.04014416866762768,
#     "recall@10": 0.043657629175434455,
#     "recall@20": 0.04413953807342325,
#     "user_hitted@01": 0.10330928202387316,
#     "user_hitted@05": 0.2466818100837342,
#     "user_hitted@10": 0.2500890789239266,
#     "user_hitted@20": 0.25011134865490825
# }
# {'MAE': Timedelta('123 days 10:49:42.331158526')}
# Boosting metrics:
# {
#     "precision@01": 0.09622750757170853,
#     "precision@05": 0.0573757349011224,
#     "precision@10": 0.042584179583110636,
#     "precision@20": 0.03014542134331017,
#     "recall@01": 0.006210307834149711,
#     "recall@05": 0.015290061213995756,
#     "recall@10": 0.020554607331040097,
#     "recall@20": 0.02591313185027256,
#     "user_hitted@01": 0.06179850347407803,
#     "user_hitted@05": 0.13121325494388028,
#     "user_hitted@10": 0.16437288437555675,
#     "user_hitted@20": 0.19503830393728844
# }
# {'MAE': Timedelta('123 days 10:49:42.331158526')}
# CPU times: user 3h 51min 15s, sys: 7min 10s, total: 3h 58min 26s
# Wall time: 13min 10s

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'tfidf_rnk', 'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.05418225547835382,
#     "precision@05": 0.03777837163727062,
#     "precision@10": 0.03234233030464991,
#     "precision@20": 0.02673369855692144,
#     "recall@01": 0.004272681476581786,
#     "recall@05": 0.011592844967787461,
#     "recall@10": 0.016970967723949168,
#     "recall@20": 0.024281546936980865,
#     "user_hitted@01": 0.03721272047033672,
#     "user_hitted@05": 0.08988063424193836,
#     "user_hitted@10": 0.1292089791555318,
#     "user_hitted@20": 0.17553001959736325
# }
# {'MAE': Timedelta('138 days 19:12:28.548176322')}
# Boosting metrics:
# {
#     "precision@01": 0.08903438446463567,
#     "precision@05": 0.05734901122394441,
#     "precision@10": 0.04454614288259398,
#     "precision@20": 0.03327097808658471,
#     "recall@01": 0.0058261127875341,
#     "recall@05": 0.01556538132323202,
#     "recall@10": 0.021984974839684607,
#     "recall@20": 0.02941338574354121,
#     "user_hitted@01": 0.058747550329592016,
#     "user_hitted@05": 0.1329725636914306,
#     "user_hitted@10": 0.17009620523784072,
#     "user_hitted@20": 0.20612862996615
# }
# {'MAE': Timedelta('138 days 19:12:28.548176322')}
# CPU times: user 1h 21min 48s, sys: 3min 29s, total: 1h 25min 17s
# Wall time: 5min 53s

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'bm25_rnk', 'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.04124354177801532,
#     "precision@05": 0.027008729734544806,
#     "precision@10": 0.022136112595759847,
#     "precision@20": 0.017884820951362908,
#     "recall@01": 0.003746752804766051,
#     "recall@05": 0.010041563152648548,
#     "recall@10": 0.01441007932931331,
#     "recall@20": 0.020587184604475617,
#     "user_hitted@01": 0.02834936753964012,
#     "user_hitted@05": 0.06741047568145377,
#     "user_hitted@10": 0.09558168537324069,
#     "user_hitted@20": 0.13424193835738465
# }
# {'MAE': Timedelta('142 days 04:45:00.025734138')}
# Boosting metrics:
# {
#     "precision@01": 0.06064047746303225,
#     "precision@05": 0.03774719401389632,
#     "precision@10": 0.029153304828077674,
#     "precision@20": 0.021405665419561733,
#     "recall@01": 0.004817466961932413,
#     "recall@05": 0.012818915897139465,
#     "recall@10": 0.017918789760641388,
#     "recall@20": 0.023788816891370808,
#     "user_hitted@01": 0.04090949581329058,
#     "user_hitted@05": 0.09357740958489222,
#     "user_hitted@10": 0.12410921076073402,
#     "user_hitted@20": 0.15577676821663994
# }
# {'MAE': Timedelta('142 days 04:45:00.025734138')}
# CPU times: user 46min 20s, sys: 2min 13s, total: 48min 34s
# Wall time: 4min 23s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'cosine_rnk', 'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {
#     "precision@01": 0.050307322287546766,
#     "precision@05": 0.035880990557634065,
#     "precision@10": 0.02967664350614645,
#     "precision@20": 0.024382014965259217,
#     "recall@01": 0.004252299013442336,
#     "recall@05": 0.0110520370240936,
#     "recall@10": 0.015590432828667997,
#     "recall@20": 0.022140438990907264,
#     "user_hitted@01": 0.03538660252984144,
#     "user_hitted@05": 0.08760912168181008,
#     "user_hitted@10": 0.12181542846962409,
#     "user_hitted@20": 0.1642615357206485
# }
# {'MAE': Timedelta('138 days 00:28:15.212026320')}
# Boosting metrics:
# {
#     "precision@01": 0.08765366114377339,
#     "precision@05": 0.05493497238553359,
#     "precision@10": 0.0421476928558703,
#     "precision@20": 0.030640922857651878,
#     "recall@01": 0.0057028911197464695,
#     "recall@05": 0.01490102211711343,
#     "recall@10": 0.02071880316866509,
#     "recall@20": 0.02690155004335435,
#     "user_hitted@01": 0.05812399786210583,
#     "user_hitted@05": 0.126336183858899,
#     "user_hitted@10": 0.16150008907892394,
#     "user_hitted@20": 0.19312310707286656
# }
# {'MAE': Timedelta('138 days 00:28:15.212026320')}
# CPU times: user 51min 59s, sys: 2min 23s, total: 54min 22s
# Wall time: 4min 39s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'markov_rnk', 'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {
#     "precision@01": 0.009731872438980937,
#     "precision@05": 0.007919116337074648,
#     "precision@10": 0.006600748262960983,
#     "precision@20": 0.00474122572599323,
#     "recall@01": 0.000496456696043045,
#     "recall@05": 0.002011732110616631,
#     "recall@10": 0.003173979428076926,
#     "recall@20": 0.004557072133553387,
#     "user_hitted@01": 0.006458221984678425,
#     "user_hitted@05": 0.025654730090860504,
#     "user_hitted@10": 0.039818278995189735,
#     "user_hitted@20": 0.05315784785319793
# }
# {'MAE': Timedelta('141 days 08:51:54.497598724')}
# Boosting metrics:
# {
#     "precision@01": 0.030487261713878496,
#     "precision@05": 0.014421877783716376,
#     "precision@10": 0.009115000890789239,
#     "precision@20": 0.005482807767682167,
#     "recall@01": 0.0017394880568300179,
#     "recall@05": 0.0035721359975198065,
#     "recall@10": 0.004462152628873647,
#     "recall@20": 0.005282825037945219,
#     "user_hitted@01": 0.019463744877961875,
#     "user_hitted@05": 0.04059771957954748,
#     "user_hitted@10": 0.048124888651345094,
#     "user_hitted@20": 0.05598610368786745
# }
# {'MAE': Timedelta('141 days 08:51:54.497598724')}
# CPU times: user 24min 59s, sys: 8min 36s, total: 33min 36s
# Wall time: 14min 48s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'apriori_rnk', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {
#     "precision@01": 0.018595225369677535,
#     "precision@05": 0.05716639942989489,
#     "precision@10": 0.04711384286477819,
#     "precision@20": 0.034650587920897924,
#     "recall@01": 0.0012084681978642945,
#     "recall@05": 0.022308280309853903,
#     "recall@10": 0.0335697352193332,
#     "recall@20": 0.04458036878186814,
#     "user_hitted@01": 0.0172813112417602,
#     "user_hitted@05": 0.1204347051487618,
#     "user_hitted@10": 0.16724567967218956,
#     "user_hitted@20": 0.20911277391769106
# }
# {'MAE': Timedelta('137 days 08:23:21.036051434')}
# Boosting metrics:
# {
#     "precision@01": 0.05516212364154641,
#     "precision@05": 0.05521557099590237,
#     "precision@10": 0.04524318546231962,
#     "precision@20": 0.034484678425084625,
#     "recall@01": 0.003928490256469379,
#     "recall@05": 0.020140845124112045,
#     "recall@10": 0.03130280620817129,
#     "recall@20": 0.04384187540863124,
#     "user_hitted@01": 0.048904329235702836,
#     "user_hitted@05": 0.13241582041688937,
#     "user_hitted@10": 0.176309460181721,
#     "user_hitted@20": 0.21891145554961697
# }
# {'MAE': Timedelta('137 days 08:23:21.036051434')}
# CPU times: user 5min 27s, sys: 30.4 s, total: 5min 57s
# Wall time: 1min 17s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 19 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'monetary', 'frequency',
#        'elasticity_client', 'cluster_cart', 'apriori_lastnext_rnk',
#        'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {
#     "precision@01": 0.02059950115802601,
#     "precision@05": 0.046744165330482805,
#     "precision@10": 0.03704124354177801,
#     "precision@20": 0.026635711740602176,
#     "recall@01": 0.001216797293788819,
#     "recall@05": 0.017779215363649317,
#     "recall@10": 0.02614741111395273,
#     "recall@20": 0.03424337977186358,
#     "user_hitted@01": 0.019085159451273828,
#     "user_hitted@05": 0.10139408515945128,
#     "user_hitted@10": 0.14023249599144844,
#     "user_hitted@20": 0.1751068947087119
# }
# {'MAE': Timedelta('136 days 12:20:52.632171612')}
# Boosting metrics:
# {
#     "precision@01": 0.046833244254409406,
#     "precision@05": 0.04725636914306075,
#     "precision@10": 0.037702654551933015,
#     "precision@20": 0.02782825583466952,
#     "recall@01": 0.0036215918259175977,
#     "recall@05": 0.01820504439837333,
#     "recall@10": 0.026635234110355774,
#     "recall@20": 0.03589464264801623,
#     "user_hitted@01": 0.042557455905932656,
#     "user_hitted@05": 0.11270710849812934,
#     "user_hitted@10": 0.15121147336540175,
#     "user_hitted@20": 0.18555139853910566
# }
# {'MAE': Timedelta('136 days 12:20:52.632171612')}
# CPU times: user 3min 22s, sys: 26.1 s, total: 3min 48s
# Wall time: 1min 15s

# %% [markdown]
# ## Таргет - category_id

# %% [markdown]
# ### 2 months

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'toppop_rnk', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {
#     "precision@01": 0.27277528386585687,
#     "precision@05": 0.28819646157908635,
#     "precision@10": 0.22222075521520993,
#     "precision@20": 0.17102587800369687,
#     "recall@01": 0.0109727458346157,
#     "recall@05": 0.06332079881224069,
#     "recall@10": 0.11906548347031141,
#     "recall@20": 0.18539419213445277,
#     "user_hitted@01": 0.031379279992958364,
#     "user_hitted@05": 0.2720271102895872,
#     "user_hitted@10": 0.42588680573893145,
#     "user_hitted@20": 0.5270662793768154
# }
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# Boosting metrics:
# {
#     "precision@01": 0.5600299269430508,
#     "precision@05": 0.33728545022445205,
#     "precision@10": 0.25512718950796587,
#     "precision@20": 0.1848142769122436,
#     "recall@01": 0.03718547062716498,
#     "recall@05": 0.09938777688335902,
#     "recall@10": 0.15214692641891805,
#     "recall@20": 0.22082322481395467,
#     "user_hitted@01": 0.17062758559985916,
#     "user_hitted@05": 0.3748789719214858,
#     "user_hitted@10": 0.49423466244168646,
#     "user_hitted@20": 0.5958102279728897
# }
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# CPU times: user 8min 25s, sys: 27.7 s, total: 8min 52s
# Wall time: 1min 20s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'usertoppop_rnk', 'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {
#     "precision@01": 0.5521080890766658,
#     "precision@05": 0.42221635419417297,
#     "precision@10": 0.36427691224364056,
#     "precision@20": 0.2334367573277,
#     "recall@01": 0.03982316796587005,
#     "recall@05": 0.14560823501735157,
#     "recall@10": 0.22734643232134008,
#     "recall@20": 0.26492564586507394,
#     "user_hitted@01": 0.1542557873426635,
#     "user_hitted@05": 0.4199894375495115,
#     "user_hitted@10": 0.4983276120059854,
#     "user_hitted@20": 0.5103864096470381
# }
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# Boosting metrics:
# {
#     "precision@01": 0.4233782237479095,
#     "precision@05": 0.2544846404365813,
#     "precision@10": 0.1903529618871578,
#     "precision@20": 0.13681013995246896,
#     "recall@01": 0.026884439770302138,
#     "recall@05": 0.08394546782099263,
#     "recall@10": 0.12195366412623798,
#     "recall@20": 0.16812724120279787,
#     "user_hitted@01": 0.10967344423906346,
#     "user_hitted@05": 0.2981691752486577,
#     "user_hitted@10": 0.38341695273303406,
#     "user_hitted@20": 0.4505325235454625
# }
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# CPU times: user 7min 30s, sys: 25.9 s, total: 7min 56s
# Wall time: 1min 24s

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'tfidf_rnk', 'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.4213097438605757,
#     "precision@05": 0.25510958542381834,
#     "precision@10": 0.20039169087228237,
#     "precision@20": 0.15123668691136344,
#     "recall@01": 0.029010171342379557,
#     "recall@05": 0.08206006204682455,
#     "recall@10": 0.12432455219267047,
#     "recall@20": 0.1821380719761652,
#     "user_hitted@01": 0.15381568523897543,
#     "user_hitted@05": 0.324575301469941,
#     "user_hitted@10": 0.4166886717718511,
#     "user_hitted@20": 0.49441070328316167
# }
# {'MAE': Timedelta('85 days 16:06:00.177666114')}
# Boosting metrics:
# {
#     "precision@01": 0.4041457618167415,
#     "precision@05": 0.24661561482263883,
#     "precision@10": 0.19654519848604876,
#     "precision@20": 0.1500924214417745,
#     "recall@01": 0.02823313256675977,
#     "recall@05": 0.07935617702507344,
#     "recall@10": 0.12223870555965084,
#     "recall@20": 0.18032577351604567,
#     "user_hitted@01": 0.15077898072352786,
#     "user_hitted@05": 0.3226828624240824,
#     "user_hitted@10": 0.4123756711557081,
#     "user_hitted@20": 0.4919461315025086
# }
# {'MAE': Timedelta('85 days 16:06:00.177666114')}
# CPU times: user 8min 51s, sys: 34.3 s, total: 9min 25s
# Wall time: 2min 51s

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'bm25_rnk', 'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.450664554176569,
#     "precision@05": 0.26604172167942963,
#     "precision@10": 0.2048895343719743,
#     "precision@20": 0.15704383416952736,
#     "recall@01": 0.031513196142105425,
#     "recall@05": 0.08942740459100194,
#     "recall@10": 0.13269096317783155,
#     "recall@20": 0.19370235836706162,
#     "user_hitted@01": 0.15491594049819557,
#     "user_hitted@05": 0.3376463339494763,
#     "user_hitted@10": 0.4247865504797113,
#     "user_hitted@20": 0.5074377255523281
# }
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# Boosting metrics:
# {
#     "precision@01": 0.43790159316961536,
#     "precision@05": 0.2628817885749494,
#     "precision@10": 0.20194085027726433,
#     "precision@20": 0.15419417304814717,
#     "recall@01": 0.030698396353218214,
#     "recall@05": 0.08837662586552521,
#     "recall@10": 0.13078535101922392,
#     "recall@20": 0.19014642245986932,
#     "user_hitted@01": 0.15381568523897543,
#     "user_hitted@05": 0.33720623184578824,
#     "user_hitted@10": 0.4225420297509022,
#     "user_hitted@20": 0.5047090925094622
# }
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# CPU times: user 9min 1s, sys: 39.1 s, total: 9min 41s
# Wall time: 2min 55s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'cosine_rnk', 'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {
#     "precision@01": 0.3743508493970601,
#     "precision@05": 0.22377431564122874,
#     "precision@10": 0.17323299005369244,
#     "precision@20": 0.13668911187395474,
#     "recall@01": 0.026000876362821904,
#     "recall@05": 0.07194845340223417,
#     "recall@10": 0.10853600216852692,
#     "recall@20": 0.16707721684767365,
#     "user_hitted@01": 0.15139512366869112,
#     "user_hitted@05": 0.31106416688671773,
#     "user_hitted@10": 0.395871842267406,
#     "user_hitted@20": 0.4812956605932576
# }
# {'MAE': Timedelta('85 days 16:49:30.090817356')}
# Boosting metrics:
# {
#     "precision@01": 0.360795704603468,
#     "precision@05": 0.21894199454273391,
#     "precision@10": 0.17014347328580232,
#     "precision@20": 0.1344247865504797,
#     "recall@01": 0.025332618721750917,
#     "recall@05": 0.07068186269907407,
#     "recall@10": 0.10620185897762491,
#     "recall@20": 0.16339064285585542,
#     "user_hitted@01": 0.14937065399172608,
#     "user_hitted@05": 0.3084675644749582,
#     "user_hitted@10": 0.3914268110201567,
#     "user_hitted@20": 0.47755479271190915
# }
# {'MAE': Timedelta('85 days 16:49:30.090817356')}
# CPU times: user 8min 53s, sys: 37.8 s, total: 9min 31s
# Wall time: 2min 54s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'markov_rnk', 'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {
#     "precision@01": 0.15297949124196814,
#     "precision@05": 0.09876771410967343,
#     "precision@10": 0.08634363172255964,
#     "precision@20": 0.07289191092333422,
#     "recall@01": 0.014248590167349168,
#     "recall@05": 0.038979464121862165,
#     "recall@10": 0.06265008719557559,
#     "recall@20": 0.10024013638128591,
#     "user_hitted@01": 0.08709620631986621,
#     "user_hitted@05": 0.21459378575829594,
#     "user_hitted@10": 0.29838922630050174,
#     "user_hitted@20": 0.38909426987060997
# }
# {'MAE': Timedelta('86 days 21:22:53.677803328')}
# Boosting metrics:
# {
#     "precision@01": 0.13163453921309745,
#     "precision@05": 0.09158524777748438,
#     "precision@10": 0.07976850629346008,
#     "precision@20": 0.06849969192852742,
#     "recall@01": 0.012459513797926716,
#     "recall@05": 0.0359282981830048,
#     "recall@10": 0.05921087170958944,
#     "recall@20": 0.09522807097713054,
#     "user_hitted@01": 0.07631370477950884,
#     "user_hitted@05": 0.20310712085203766,
#     "user_hitted@10": 0.2857582959246545,
#     "user_hitted@20": 0.3798961359035296
# }
# {'MAE': Timedelta('86 days 21:22:53.677803328')}
# CPU times: user 12min 38s, sys: 3min 15s, total: 15min 53s
# Wall time: 9min 50s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'apriori_rnk', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {
#     "precision@01": 0.06293460082739195,
#     "precision@05": 0.12445207288090836,
#     "precision@10": 0.11952292931960215,
#     "precision@20": 0.08964879852125693,
#     "recall@01": 0.0043559849180269325,
#     "recall@05": 0.06756276402475885,
#     "recall@10": 0.12015909890036848,
#     "recall@20": 0.17264811305744185,
#     "user_hitted@01": 0.03063110641668867,
#     "user_hitted@05": 0.19192852741836106,
#     "user_hitted@10": 0.2938121644221459,
#     "user_hitted@20": 0.4005369245664994
# }
# {'MAE': Timedelta('88 days 04:18:26.325307963')}
# Boosting metrics:
# {
#     "precision@01": 0.1502508581991022,
#     "precision@05": 0.2353313968840771,
#     "precision@10": 0.16004753102719832,
#     "precision@20": 0.1045286506469501,
#     "recall@01": 0.009332448325309882,
#     "recall@05": 0.11269063123709616,
#     "recall@10": 0.14771042705801257,
#     "recall@20": 0.18752485333429814,
#     "user_hitted@01": 0.05985388610157556,
#     "user_hitted@05": 0.30283425754775106,
#     "user_hitted@10": 0.3759352169703371,
#     "user_hitted@20": 0.4454713493530499
# }
# {'MAE': Timedelta('88 days 04:18:26.325307963')}
# CPU times: user 4min 19s, sys: 22.2 s, total: 4min 41s
# Wall time: 59.3 s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'apriori_lastnext_rnk', 'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {
#     "precision@01": 0.050039609189331924,
#     "precision@05": 0.1257811812340463,
#     "precision@10": 0.12011706715958104,
#     "precision@20": 0.08834389578382185,
#     "recall@01": 0.004084466005540476,
#     "recall@05": 0.06372231634455376,
#     "recall@10": 0.11593701973411902,
#     "recall@20": 0.16395754604243756,
#     "user_hitted@01": 0.027110289587184228,
#     "user_hitted@05": 0.18479887333861456,
#     "user_hitted@10": 0.28910307191268375,
#     "user_hitted@20": 0.3894903617639292
# }
# {'MAE': Timedelta('88 days 00:56:06.095306471')}
# Boosting metrics:
# {
#     "precision@01": 0.1068127805650911,
#     "precision@05": 0.2421089692808732,
#     "precision@10": 0.16158348736906963,
#     "precision@20": 0.10312692544670364,
#     "recall@01": 0.005689247131727826,
#     "recall@05": 0.11882290549436325,
#     "recall@10": 0.15033387669903084,
#     "recall@20": 0.18420688466191382,
#     "user_hitted@01": 0.04423026142064959,
#     "user_hitted@05": 0.3151131062406478,
#     "user_hitted@10": 0.37809171727840857,
#     "user_hitted@20": 0.4396620015843676
# }
# {'MAE': Timedelta('88 days 00:56:06.095306471')}
# CPU times: user 4min 21s, sys: 21.8 s, total: 4min 43s
# Wall time: 1min 1s

# %% [markdown]
# ### 6 months

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'toppop_rnk', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {
#     "precision@01": 0.38433101728131125,
#     "precision@05": 0.44970158560484585,
#     "precision@10": 0.34841216818100834,
#     "precision@20": 0.2716484054872617,
#     "recall@01": 0.010691564815232505,
#     "recall@05": 0.061174867340685675,
#     "recall@10": 0.11367450140927662,
#     "recall@20": 0.1833428650695144,
#     "user_hitted@01": 0.04471761981115268,
#     "user_hitted@05": 0.31148672724033494,
#     "user_hitted@10": 0.45721984678425087,
#     "user_hitted@20": 0.5562978799216105
# }
# {'MAE': Timedelta('149 days 08:38:03.431032420')}
# Boosting metrics:
# {
#     "precision@01": 0.7820684126135756,
#     "precision@05": 0.4886112595759844,
#     "precision@10": 0.3754075360769642,
#     "precision@20": 0.28396468020666316,
#     "recall@01": 0.034408372045168084,
#     "recall@05": 0.09670354090886367,
#     "recall@10": 0.14685501703188292,
#     "recall@20": 0.2177225598997489,
#     "user_hitted@01": 0.20283270978086584,
#     "user_hitted@05": 0.41508551576696956,
#     "user_hitted@10": 0.5294851238197043,
#     "user_hitted@20": 0.6235301977552111
# }
# {'MAE': Timedelta('149 days 08:38:03.431032420')}
# CPU times: user 8min 3s, sys: 29.4 s, total: 8min 32s
# Wall time: 1min 34s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'usertoppop_rnk', 'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {
#     "precision@01": 0.7181765544272225,
#     "precision@05": 0.5767593087475504,
#     "precision@10": 0.49567076429716733,
#     "precision@20": 0.3177345002672367,
#     "recall@01": 0.029663101249031536,
#     "recall@05": 0.10778305707510778,
#     "recall@10": 0.15838158506963168,
#     "recall@20": 0.17724357162143448,
#     "user_hitted@01": 0.15366114377338322,
#     "user_hitted@05": 0.36217263495456975,
#     "user_hitted@10": 0.3932166399429895,
#     "user_hitted@20": 0.3955549616960627
# }
# {'MAE': Timedelta('139 days 18:21:13.076687678')}
# Boosting metrics:
# {
#     "precision@01": 0.5495056119722074,
#     "precision@05": 0.3427400676999822,
#     "precision@10": 0.2579658827721361,
#     "precision@20": 0.18548681631925887,
#     "recall@01": 0.01984572963903345,
#     "recall@05": 0.060856366701346504,
#     "recall@10": 0.0884214072074452,
#     "recall@20": 0.11936720664473247,
#     "user_hitted@01": 0.10918849100302869,
#     "user_hitted@05": 0.2716239087831819,
#     "user_hitted@10": 0.3324202743630857,
#     "user_hitted@20": 0.37165954035275256
# }
# {'MAE': Timedelta('139 days 18:21:13.076687678')}
# CPU times: user 7min 8s, sys: 27.4 s, total: 7min 36s
# Wall time: 1min 29s

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'tfidf_rnk', 'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {
#     "precision@01": 0.5982540530910386,
#     "precision@05": 0.35906823445572783,
#     "precision@10": 0.2826630144307857,
#     "precision@20": 0.21597185106003924,
#     "recall@01": 0.02270874532856474,
#     "recall@05": 0.06414666749790826,
#     "recall@10": 0.09652422327493951,
#     "recall@20": 0.14301528918166162,
#     "user_hitted@01": 0.1629698913237128,
#     "user_hitted@05": 0.30558524853019775,
#     "user_hitted@10": 0.36961072510244075,
#     "user_hitted@20": 0.42579725636914306
# }
# {'MAE': Timedelta('149 days 13:42:23.159909754')}
# Boosting metrics:
# {
#     "precision@01": 0.5708622839836095,
#     "precision@05": 0.3519018350258329,
#     "precision@10": 0.2765544272225191,
#     "precision@20": 0.21297434526990916,
#     "recall@01": 0.021467345715239353,
#     "recall@05": 0.06332153762672844,
#     "recall@10": 0.0950000051393383,
#     "recall@20": 0.14139377359364586,
#     "user_hitted@01": 0.1600080171031534,
#     "user_hitted@05": 0.3052957420274363,
#     "user_hitted@10": 0.3678068768929271,
#     "user_hitted@20": 0.42441653304828075
# }
# {'MAE': Timedelta('149 days 13:42:23.159909756')}
# CPU times: user 8min 30s, sys: 37.7 s, total: 9min 8s
# Wall time: 2min 49s

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'bm25_rnk', 'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {
#     "precision@01": 0.6302556565116694,
#     "precision@05": 0.37121414573311956,
#     "precision@10": 0.2855959380010689,
#     "precision@20": 0.22034451273828612,
#     "recall@01": 0.024359796240001102,
#     "recall@05": 0.0687857276842745,
#     "recall@10": 0.10258838373619106,
#     "recall@20": 0.15135924024345607,
#     "user_hitted@01": 0.16101015499732763,
#     "user_hitted@05": 0.31128629966150007,
#     "user_hitted@10": 0.3760912168181008,
#     "user_hitted@20": 0.43474968822376625
# }
# {'MAE': Timedelta('149 days 18:01:29.407337724')}
# Boosting metrics:
# {
#     "precision@01": 0.6058257616247996,
#     "precision@05": 0.3646802066631036,
#     "precision@10": 0.2782625155888117,
#     "precision@20": 0.21660653839301622,
#     "recall@01": 0.02341978493162312,
#     "recall@05": 0.06790577520417522,
#     "recall@10": 0.10065450130620786,
#     "recall@20": 0.1498382624612099,
#     "user_hitted@01": 0.16125512203812578,
#     "user_hitted@05": 0.31148672724033494,
#     "user_hitted@10": 0.3746882237662569,
#     "user_hitted@20": 0.434192944949225
# }
# {'MAE': Timedelta('149 days 18:01:29.407337724')}
# CPU times: user 8min 34s, sys: 37.7 s, total: 9min 12s
# Wall time: 2min 49s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'cosine_rnk', 'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {
#     "precision@01": 0.544316764653483,
#     "precision@05": 0.3179449492250133,
#     "precision@10": 0.24769508284339925,
#     "precision@20": 0.19691452877249244,
#     "recall@01": 0.020795069332024293,
#     "recall@05": 0.05702166296361622,
#     "recall@10": 0.08584954140268698,
#     "recall@20": 0.13289216574900503,
#     "user_hitted@01": 0.16236860858720828,
#     "user_hitted@05": 0.2966996258685195,
#     "user_hitted@10": 0.3597006948156066,
#     "user_hitted@20": 0.42051933012649206
# }
# {'MAE': Timedelta('149 days 14:37:40.007695266')}
# Boosting metrics:
# {
#     "precision@01": 0.5326028861571352,
#     "precision@05": 0.31060484589346166,
#     "precision@10": 0.24182032781044002,
#     "precision@20": 0.19333800997683948,
#     "recall@01": 0.020197226766342963,
#     "recall@05": 0.055925031971865616,
#     "recall@10": 0.08406955072993809,
#     "recall@20": 0.1304147134147243,
#     "user_hitted@01": 0.16132193123107072,
#     "user_hitted@05": 0.2947398895421343,
#     "user_hitted@10": 0.35713967575271693,
#     "user_hitted@20": 0.4186709424550151
# }
# {'MAE': Timedelta('149 days 14:37:40.007695268')}
# CPU times: user 8min 24s, sys: 35.9 s, total: 9min
# Wall time: 2min 48s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'markov_rnk', 'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {
#     "precision@01": 0.16675574559059328,
#     "precision@05": 0.1260244076251559,
#     "precision@10": 0.11085649385355424,
#     "precision@20": 0.0950605736682701,
#     "recall@01": 0.007431510414552196,
#     "recall@05": 0.026120424182804743,
#     "recall@10": 0.044897082033148045,
#     "recall@20": 0.07486043974896055,
#     "user_hitted@01": 0.07972563691430608,
#     "user_hitted@05": 0.20521557099590237,
#     "user_hitted@10": 0.27748084803135575,
#     "user_hitted@20": 0.35054783538214856
# }
# {'MAE': Timedelta('150 days 06:21:13.340956180')}
# Boosting metrics:
# {
#     "precision@01": 0.1295207553892749,
#     "precision@05": 0.11126402993051844,
#     "precision@10": 0.10061909852128988,
#     "precision@20": 0.0875512203812578,
#     "recall@01": 0.005751666307251666,
#     "recall@05": 0.02335425090561374,
#     "recall@10": 0.04063372011278068,
#     "recall@20": 0.06967331444937522,
#     "user_hitted@01": 0.06204347051487618,
#     "user_hitted@05": 0.1896935685016925,
#     "user_hitted@10": 0.26173614822732943,
#     "user_hitted@20": 0.3397024763940852
# }
# {'MAE': Timedelta('150 days 06:21:13.340956180')}
# CPU times: user 11min 29s, sys: 2min 49s, total: 14min 18s
# Wall time: 8min 29s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'apriori_rnk', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {
#     "precision@01": 0.046944592909317656,
#     "precision@05": 0.08044717619811154,
#     "precision@10": 0.0781088544450383,
#     "precision@20": 0.06244321218599679,
#     "recall@01": 0.0019297092419378727,
#     "recall@05": 0.027969458678076216,
#     "recall@10": 0.04999279687338307,
#     "recall@20": 0.07289371753568932,
#     "user_hitted@01": 0.021334402280420453,
#     "user_hitted@05": 0.11871993586317477,
#     "user_hitted@10": 0.1807856761090326,
#     "user_hitted@20": 0.24783983609477997
# }
# {'MAE': Timedelta('148 days 07:06:51.089159664')}
# Boosting metrics:
# {
#     "precision@01": 0.13580081952610012,
#     "precision@05": 0.13397915553180118,
#     "precision@10": 0.0992250133618386,
#     "precision@20": 0.07020866737929805,
#     "recall@01": 0.0039247779976596545,
#     "recall@05": 0.028607850073051607,
#     "recall@10": 0.04346786115256965,
#     "recall@20": 0.06378347976155255,
#     "user_hitted@01": 0.042223409941207914,
#     "user_hitted@05": 0.14357295563869588,
#     "user_hitted@10": 0.19316764653482985,
#     "user_hitted@20": 0.2498663816141101
# }
# {'MAE': Timedelta('148 days 07:06:51.089159664')}
# CPU times: user 4min 6s, sys: 24.7 s, total: 4min 31s
# Wall time: 1min 7s

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 15 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'monetary', 'frequency', 'elasticity_client', 'cluster_cart',
#        'apriori_lastnext_rnk', 'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {
#     "precision@01": 0.03291466239087832,
#     "precision@05": 0.07670140744699805,
#     "precision@10": 0.07544984856582933,
#     "precision@20": 0.058479200071263136,
#     "recall@01": 0.0018873221111840187,
#     "recall@05": 0.02525649095647728,
#     "recall@10": 0.04662856626405379,
#     "recall@20": 0.06742389522926995,
#     "user_hitted@01": 0.01899608052734723,
#     "user_hitted@05": 0.11041332620701942,
#     "user_hitted@10": 0.1720559415642259,
#     "user_hitted@20": 0.23481204347051488
# }
# {'MAE': Timedelta('148 days 02:27:19.909239078')}
# Boosting metrics:
# {
#     "precision@01": 0.10451184749688223,
#     "precision@05": 0.131979333689649,
#     "precision@10": 0.09525877427400677,
#     "precision@20": 0.06590392838054517,
#     "recall@01": 0.0030454998453360842,
#     "recall@05": 0.03229746583297498,
#     "recall@10": 0.04617543041955229,
#     "recall@20": 0.0642652854979913,
#     "user_hitted@01": 0.03289239265989667,
#     "user_hitted@05": 0.14628986281845716,
#     "user_hitted@10": 0.19388027792624266,
#     "user_hitted@20": 0.24456618564047747
# }
# {'MAE': Timedelta('148 days 02:27:19.909239082')}
# CPU times: user 4min 4s, sys: 23.4 s, total: 4min 28s
# Wall time: 1min 7s
