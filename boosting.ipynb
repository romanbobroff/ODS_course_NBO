# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import warnings

from lib.pipelines import boosting_pipeline

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Таргет - item_id

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'tfidf_rnk',
#        'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {'recall@1': 0.006983712078973833, 'recall@5': 0.018679016767909295, 'recall@10': 0.026707643211061866, 'recall@20': 0.03729350317623011}
# {'MAE': Timedelta('78 days 06:13:29.018595586')}
# Boosting metrics:
# ...

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'bm25_rnk',
#        'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.006539832329996938, 'recall@5': 0.01670276020492628, 'recall@10': 0.024089110042406377, 'recall@20': 0.03320416441038049}
# {'MAE': Timedelta('77 days 21:22:08.606436857')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'cosine_rnk',
#        'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {'recall@1': 0.007197878884606339, 'recall@5': 0.017878622032876285, 'recall@10': 0.0246082056328666, 'recall@20': 0.033958830244659975}
# {'MAE': Timedelta('76 days 23:23:08.518857266')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'markov_rnk',
#        'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {'recall@1': 0.000535708870908151, 'recall@5': 0.0025018226771402036, 'recall@10': 0.004281734616768277, 'recall@20': 0.006389964512905145}
# {'MAE': Timedelta('78 days 15:02:22.033932336')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
#         item_id  user_id
# 0         18296       52
# 1         26681        2
# 2         32173        9
# 3         32539       16
# 4         38071      111
# ...         ...      ...
# 72544  89881864        4
# 72545  89888961       14
# 72546  89893310        3
# 72547  89893318        2
# 72548  89893333        4
#
# [72549 rows x 2 columns]
#      item_id
# 0   12639223
# 1   10690746
# 2   15163427
# 3   13098932
# 4   81995979
# 5   81956695
# 6   12026910
# 7   14051984
# 8   11874002
# 9   12902706
# 10  13738928
# 11  12095326
# 12  12186228
# 13  82194956
# 14  18149591
# 15  82664800
# 16  16804290
# 17    864313
# 18  13738901
# 19  82169231
# 20  12095334
# 21  11011661
# 22  15441618
# 23  10073940
# 24  81956704
# 25  82366338
# 26  12902845
# 27  13654484
# 28  12346148
# 29  13537712
# 30  82194829
# 31  17983613
# 32  12757510
# 33  17026338
# 34  15441600
# 35  15604376
# 36  10072745
# 37  82019008
# 38  11011629
# 39  14394434
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'usertoppop_rnk',
#        'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {'recall@1': 0.02225107275119123, 'recall@5': 0.06728594277385949, 'recall@10': 0.07470689119495301, 'recall@20': 0.07594869798443386}
# {'MAE': Timedelta('69 days 09:10:20.210344331')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'apriori_rnk',
#        'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {'recall@1': 0.0023884125016240634, 'recall@5': 0.06282914199373194, 'recall@10': 0.09867909498138967, 'recall@20': 0.1347504473871353}
# {'MAE': Timedelta('76 days 12:07:43.103474493')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart',
#        'apriori_lastnext_rnk', 'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {'recall@1': 0.0028251689884108036, 'recall@5': 0.05906806081047408, 'recall@10': 0.09262906030378913, 'recall@20': 0.12808243804401193}
# {'MAE': Timedelta('76 days 15:08:45.669615305')}
# Boosting metrics:
# ...

# %% [markdown]
# ### 6 months

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# tfidf metrics:
# {'recall@1': 0.0026909281545408996, 'recall@1_users': 0.004272681476581786, 'users_hitted@1': 0.03721272047033672, 'recall@5': 0.00938119712569499, 'recall@5_users': 0.011592844967787461, 'users_hitted@5': 0.08988063424193836, 'recall@10': 0.016062617997697284, 'recall@10_users': 0.016970967723949168, 'users_hitted@10': 0.1292089791555318, 'recall@20': 0.02655425156694306, 'recall@20_users': 0.024281546936980865, 'users_hitted@20': 0.17553001959736325}
# {'MAE': Timedelta('138 days 19:12:28.548176322')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# bm25 metrics:
# {'recall@1': 0.0020483349536414906, 'recall@1_users': 0.003746752804766051, 'users_hitted@1': 0.02834936753964012, 'recall@5': 0.006706859157063714, 'recall@5_users': 0.010041563152648548, 'users_hitted@5': 0.06741047568145377, 'recall@10': 0.010993763196110376, 'recall@10_users': 0.01441007932931331, 'users_hitted@10': 0.09558168537324069, 'recall@20': 0.01776477107202463, 'recall@20_users': 0.020587184604475617, 'users_hitted@20': 0.13424193835738465}
# {'MAE': Timedelta('142 days 04:45:00.025734138')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# cosine metrics:
# {'recall@1': 0.0024984819979892697, 'recall@1_users': 0.004252299013442336, 'users_hitted@1': 0.03538660252984144, 'recall@5': 0.008910035845861688, 'recall@5_users': 0.0110520370240936, 'users_hitted@5': 0.08760912168181008, 'recall@10': 0.014738721162109343, 'recall@10_users': 0.015590432828667997, 'users_hitted@10': 0.12181542846962409, 'recall@20': 0.0242183533908681, 'recall@20_users': 0.022140438990907264, 'users_hitted@20': 0.1642615357206485}
# {'MAE': Timedelta('138 days 00:28:15.212026320')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# markov metrics:
# {'recall@1': 0.00048332741616702557, 'recall@1_users': 0.000496456696043045, 'users_hitted@1': 0.006458221984678425, 'recall@5': 0.0019664900364873487, 'recall@5_users': 0.002011732110616631, 'users_hitted@5': 0.025654730090860504, 'recall@10': 0.0032782207357415646, 'recall@10_users': 0.003173979428076926, 'users_hitted@10': 0.039818278995189735, 'recall@20': 0.004709400773545068, 'recall@20_users': 0.004557072133553387, 'users_hitted@20': 0.05315784785319793}
# {'MAE': Timedelta('141 days 08:51:54.497598724')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# toppop metrics:
# {'recall@1': 0.0036996114578459966, 'recall@1_users': 0.004301904297939997, 'users_hitted@1': 0.04623196151790487, 'recall@5': 0.011850922801440913, 'recall@5_users': 0.013929633360564657, 'users_hitted@5': 0.12758328879387137, 'recall@10': 0.016683090950717194, 'recall@10_users': 0.02005287407265937, 'users_hitted@10': 0.16455104222340994, 'recall@20': 0.027039791007898033, 'recall@20_users': 0.02734711197228071, 'users_hitted@20': 0.22969000534473544}
# {'MAE': Timedelta('144 days 11:32:17.294155012')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# usertoppop metrics:
# {'recall@1': 0.009511706588184028, 'recall@1_users': 0.013556174557401511, 'users_hitted@1': 0.10330928202387316, 'recall@5': 0.055541730400630866, 'recall@5_users': 0.04014416866762768, 'users_hitted@5': 0.2466818100837342, 'recall@10': 0.07186979137288213, 'recall@10_users': 0.043657629175434455, 'users_hitted@10': 0.2500890789239266, 'recall@20': 0.07809885317574869, 'recall@20_users': 0.04413953807342325, 'users_hitted@20': 0.25011134865490825}
# {'MAE': Timedelta('123 days 10:49:42.331158526')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.018060636387784545, 'recall@5_users': 0.01516339858351044, 'users_hitted@5': 0.11535720648494566, 'recall@10': 0.0334315306206105, 'recall@10_users': 0.0231941857998457, 'users_hitted@10': 0.13916354890432925, 'recall@20': 0.057563576173176555, 'recall@20_users': 0.031911689570846384, 'users_hitted@20': 0.15165686798503475}
# {'MAE': Timedelta('115 days 16:31:17.596682418')}
# Boosting metrics:
# {'recall@1': 0.004520272654175363, 'recall@1_users': 0.004700341609669996, 'users_hitted@1': 0.07656333511491181, 'recall@5': 0.02314394130153468, 'recall@5_users': 0.016989190404278754, 'users_hitted@5': 0.12998841973988953, 'recall@10': 0.0399882196515269, 'recall@10_users': 0.02503822351542128, 'users_hitted@10': 0.14642348120434706, 'recall@20': 0.06505055660106536, 'recall@20_users': 0.03301807447094735, 'users_hitted@20': 0.15270354534117228}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.026898297006249045, 'recall@5_users': 0.02415094867326761, 'users_hitted@5': 0.17319169784429003, 'recall@10': 0.04926570137616425, 'recall@10_users': 0.03702007117103575, 'users_hitted@10': 0.20750935328701228, 'recall@20': 0.08079692331922265, 'recall@20_users': 0.049919405071998574, 'users_hitted@20': 0.22790842686620347}
# {'MAE': Timedelta('122 days 11:05:09.960735040')}
# Boosting metrics:
# {'recall@1': 0.005388492383445649, 'recall@1_users': 0.00608193124618382, 'users_hitted@1': 0.09246392303580973, 'recall@5': 0.030367941759932224, 'recall@5_users': 0.0252320700469132, 'users_hitted@5': 0.17726705861393194, 'recall@10': 0.05388787066051071, 'recall@10_users': 0.03770251176738472, 'users_hitted@10': 0.2106048458934616, 'recall@20': 0.08724728751596658, 'recall@20_users': 0.05073381523331182, 'users_hitted@20': 0.23176109032602887}
# ...

# %% [markdown]
# ## Таргет - category_id

# %% [markdown]
# ### 2 months

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'tfidf_rnk', 'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {'recall@1': 0.029010171342379557, 'recall@5': 0.08206006204682455, 'recall@10': 0.12432455219267047, 'recall@20': 0.1821380719761652}
# {'MAE': Timedelta('85 days 16:06:00.177666114')}
# Boosting metrics:
# {'recall@1': 0.02849568166279221, 'recall@5': 0.08022953182145771, 'recall@10': 0.12229592564647784, 'recall@20': 0.1794769626503292}
# {'MAE': Timedelta('85 days 16:06:00.177666114')}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'bm25_rnk', 'bm25_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.031513196142105425, 'recall@5': 0.08942740459100194, 'recall@10': 0.13269096317783155, 'recall@20': 0.19370235836706162}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# Boosting metrics:
# {'recall@1': 0.03058491335813829, 'recall@5': 0.08837979830332994, 'recall@10': 0.13127705997427805, 'recall@20': 0.19086495092218841}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'cosine_rnk', 'cosine_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# cosine metrics:
# {'recall@1': 0.026000876362821904, 'recall@5': 0.07194845340223417, 'recall@10': 0.10853600216852692, 'recall@20': 0.16707721684767365}
# {'MAE': Timedelta('85 days 16:49:30.090817356')}
# Boosting metrics:
# {'recall@1': 0.02538714789503247, 'recall@5': 0.0709809448305191, 'recall@10': 0.1063120723961201, 'recall@20': 0.16320246802866017}
# {'MAE': Timedelta('85 days 16:49:30.090817356')}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'markov_rnk', 'markov_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# markov metrics:
# {'recall@1': 0.014248590167349168, 'recall@5': 0.038979464121862165, 'recall@10': 0.06265008719557559, 'recall@20': 0.10024013638128591}
# {'MAE': Timedelta('86 days 21:22:53.677803328')}
# Boosting metrics:
# {'recall@1': 0.012733810894372042, 'recall@5': 0.036165622460358905, 'recall@10': 0.059273580419109795, 'recall@20': 0.09521742372854096}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov', # full
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'toppop_rnk', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {'recall@1': 0.0109727458346157, 'recall@5': 0.06332079881224069, 'recall@10': 0.11906548347031141, 'recall@20': 0.18539419213445277}
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# Boosting metrics:
# {'recall@1': 0.03543670217045353, 'recall@5': 0.09539130058793757, 'recall@10': 0.15118690975400487, 'recall@20': 0.21994969931327252}
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'usertoppop_rnk', 'usertoppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# usertoppop metrics:
# {'recall@1': 0.03982316796587005, 'recall@5': 0.14560823501735157, 'recall@10': 0.22734643232134008, 'recall@20': 0.26492564586507394}
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# Boosting metrics:
# {'recall@1': 0.02709477546434643, 'recall@5': 0.08453908769910208, 'recall@10': 0.12205288907099476, 'recall@20': 0.16803319819588297}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'apriori_rnk', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori metrics:
# {'recall@1': 0.002199233669000553, 'recall@5': 0.06745352816661705, 'recall@10': 0.1280932957611194, 'recall@20': 0.1894718540784207}
# {'MAE': Timedelta('88 days 00:05:34.023128423')}
# Boosting metrics:
# {'recall@1': 0.01072757271924369, 'recall@5': 0.09668923992822408, 'recall@10': 0.1370300247094387, 'recall@20': 0.18581145529313417}
# {'MAE': Timedelta('88 days 00:05:34.023128423')}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 16 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'apriori_lastnext_rnk', 'apriori_lastnext_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {'recall@1': 0.002916610934997749, 'recall@5': 0.0622078965485669, 'recall@10': 0.12141247539543387, 'recall@20': 0.17789525732669045}
# {'MAE': Timedelta('87 days 19:28:55.001467898')}
# Boosting metrics:
# {'recall@1': 0.007500727276898156, 'recall@5': 0.10003478745821735, 'recall@10': 0.13561082397499208, 'recall@20': 0.17920651601723472}
# ...

# %% [markdown]
# #### Combinations

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 18 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'bm25_rnk', 'toppop_rnk', 'bm25_score', 'toppop_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.031513196142105425, 'recall@5': 0.08942740459100194, 'recall@10': 0.13269096317783155, 'recall@20': 0.19370235836706162}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# toppop metrics:
# {'recall@1': 0.0109727458346157, 'recall@5': 0.06332079881224069, 'recall@10': 0.11906548347031141, 'recall@20': 0.18539419213445277}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 18 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'toppop_rnk', 'apriori_rnk', 'toppop_score',
#        'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# toppop metrics:
# {'recall@1': 0.0109727458346157, 'recall@5': 0.06332079881224069, 'recall@10': 0.11906548347031141, 'recall@20': 0.18539419213445277}
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# apriori metrics:
# {'recall@1': 0.002199233669000553, 'recall@5': 0.06745352816661705, 'recall@10': 0.1280932957611194, 'recall@20': 0.1894718540784207}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 20 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'bm25_rnk', 'toppop_rnk', 'apriori_rnk', 'bm25_score',
#        'toppop_score', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.031513196142105425, 'recall@5': 0.08942740459100194, 'recall@10': 0.13269096317783155, 'recall@20': 0.19370235836706162}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# toppop metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 22 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'bm25_rnk', 'toppop_rnk', 'usertoppop_rnk',
#        'apriori_rnk', 'bm25_score', 'toppop_score', 'usertoppop_score',
#        'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.031513196142105425, 'recall@5': 0.08942740459100194, 'recall@10': 0.13269096317783155, 'recall@20': 0.19370235836706162}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# toppop metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    'markov',
    'toppop',
    'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# 24 features
# Index(['ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'bm25_rnk', 'markov_rnk', 'toppop_rnk',
#        'usertoppop_rnk', 'apriori_rnk', 'bm25_score', 'markov_score',
#        'toppop_score', 'usertoppop_score', 'apriori_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# bm25 metrics:
# {'recall@1': 0.031513196142105425, 'recall@5': 0.08942740459100194, 'recall@10': 0.13269096317783155, 'recall@20': 0.19370235836706162}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# markov metrics:
# ...

# %% [markdown]
# ### 6 months

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# tfidf metrics:
# {'recall@1': 0.02971191695174136, 'recall@1_users': 0.02270874532856474, 'users_hitted@1': 0.1629698913237128, 'recall@5': 0.08916450717746743, 'recall@5_users': 0.06414666749790826, 'users_hitted@5': 0.30558524853019775, 'recall@10': 0.14038283513005045, 'recall@10_users': 0.09652422327493951, 'users_hitted@10': 0.36961072510244075, 'recall@20': 0.21452216393536905, 'recall@20_users': 0.14301528918166162, 'users_hitted@20': 0.42579725636914306}
# {'MAE': Timedelta('149 days 13:42:23.159909754')}
# Boosting metrics:
# {'recall@1': 0.028478713132459362, 'recall@1_users': 0.021737645727127244, 'users_hitted@1': 0.16096561553536434, 'recall@5': 0.08773664517684585, 'recall@5_users': 0.06343205998477598, 'users_hitted@5': 0.3052066631035097, 'recall@10': 0.1375978959220217, 'recall@10_users': 0.09529907680922918, 'users_hitted@10': 0.36831908070550506, 'recall@20': 0.21104043691913613, 'recall@20_users': 0.14069175680172394, 'users_hitted@20': 0.4248173882059505}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# bm25 metrics:
# {'recall@1': 0.03130125676188327, 'recall@1_users': 0.024359796240001102, 'users_hitted@1': 0.16101015499732763, 'recall@5': 0.09218060297583695, 'recall@5_users': 0.0687857276842745, 'users_hitted@5': 0.31128629966150007, 'recall@10': 0.1418394534529154, 'recall@10_users': 0.10258838373619106, 'users_hitted@10': 0.3760912168181008, 'recall@20': 0.21886547460650843, 'recall@20_users': 0.15135924024345607, 'users_hitted@20': 0.43474968822376625}
# {'MAE': Timedelta('149 days 18:01:29.407337722')}
# Boosting metrics:
# {'recall@1': 0.03035893420221667, 'recall@1_users': 0.023713425486735225, 'users_hitted@1': 0.1613887404240157, 'recall@5': 0.09093523302022122, 'recall@5_users': 0.06798215428125401, 'users_hitted@5': 0.3114421877783716, 'recall@10': 0.1386640918698135, 'recall@10_users': 0.10059240490066251, 'users_hitted@10': 0.37488865134509175, 'recall@20': 0.21516918118584435, 'recall@20_users': 0.14959090168452674, 'users_hitted@20': 0.43432656333511493}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# cosine metrics:
# {'recall@1': 0.027033154933534184, 'recall@1_users': 0.020795069332024293, 'users_hitted@1': 0.16236860858720828, 'recall@5': 0.0789526947438973, 'recall@5_users': 0.05702166296361622, 'users_hitted@5': 0.2966996258685195, 'recall@10': 0.12301622851985679, 'recall@10_users': 0.08584954140268698, 'users_hitted@10': 0.3597006948156066, 'recall@20': 0.19559276181248886, 'recall@20_users': 0.13289216574900503, 'users_hitted@20': 0.42051933012649206}
# {'MAE': Timedelta('149 days 14:37:40.007695268')}
# Boosting metrics:
# {'recall@1': 0.026510011071184062, 'recall@1_users': 0.02040735850699432, 'users_hitted@1': 0.1618564047746303, 'recall@5': 0.07717201478959773, 'recall@5_users': 0.05594903788537409, 'users_hitted@5': 0.2949180473899875, 'recall@10': 0.11992492387869698, 'recall@10_users': 0.08415379471938009, 'users_hitted@10': 0.35729556386958844, 'recall@20': 0.19232007113871719, 'recall@20_users': 0.13107482393351505, 'users_hitted@20': 0.42027436308569394}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# markov metrics:
# {'recall@1': 0.008281820806083954, 'recall@1_users': 0.007431510414552196, 'users_hitted@1': 0.07972563691430608, 'recall@5': 0.031294620687519425, 'recall@5_users': 0.026120424182804743, 'users_hitted@5': 0.20521557099590237, 'recall@10': 0.05505619095967589, 'recall@10_users': 0.044897082033148045, 'users_hitted@10': 0.27748084803135575, 'recall@20': 0.09442249009842404, 'recall@20_users': 0.07486043974896055, 'users_hitted@20': 0.35054783538214856}
# {'MAE': Timedelta('150 days 06:21:13.340956180')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# toppop metrics:
# {'recall@1': 0.019087561895218597, 'recall@1_users': 0.010691564815232505, 'users_hitted@1': 0.04471761981115268, 'recall@5': 0.1116707533824624, 'recall@5_users': 0.061174867340685675, 'users_hitted@5': 0.31148672724033494, 'recall@10': 0.17303674504976502, 'recall@10_users': 0.11367450140927662, 'users_hitted@10': 0.45721984678425087, 'recall@20': 0.26982499565890133, 'recall@20_users': 0.1833428650695144, 'users_hitted@20': 0.5562978799216105}
# {'MAE': Timedelta('149 days 08:38:03.431032420')}
# Boosting metrics:
# {'recall@1': 0.035291749479344665, 'recall@1_users': 0.02659320238556184, 'users_hitted@1': 0.1798503474078033, 'recall@5': 0.11851144003919709, 'recall@5_users': 0.08759566653248535, 'users_hitted@5': 0.39328344913593444, 'recall@10': 0.18502038933848292, 'recall@10_users': 0.14138454248733934, 'users_hitted@10': 0.5184170675218244, 'recall@20': 0.2803874140213615, 'recall@20_users': 0.21130611012906564, 'users_hitted@20': 0.6128407268840192}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# usertoppop metrics:
# {'recall@1': 0.035667793693296125, 'recall@1_users': 0.029663101249031536, 'users_hitted@1': 0.15366114377338322, 'recall@5': 0.143221968945384, 'recall@5_users': 0.10778305707510778, 'users_hitted@5': 0.36217263495456975, 'recall@10': 0.24617181460135443, 'recall@10_users': 0.15838158506963168, 'users_hitted@10': 0.3932166399429895, 'recall@20': 0.31560174263312796, 'recall@20_users': 0.17724357162143448, 'users_hitted@20': 0.3955549616960627}
# {'MAE': Timedelta('139 days 18:21:13.076687678')}
# Boosting metrics:
# {'recall@1': 0.027607175366007153, 'recall@1_users': 0.019673441517327073, 'users_hitted@1': 0.10885444503830394, 'recall@5': 0.08583762189639096, 'recall@5_users': 0.061309919097083575, 'users_hitted@5': 0.2721583823267415, 'recall@10': 0.12866131577870463, 'recall@10_users': 0.08857968553253731, 'users_hitted@10': 0.332464813825049, 'recall@20': 0.18401170603517783, 'recall@20_users': 0.11941286138642375, 'users_hitted@20': 0.37179315873864244}
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Add features...
# Fit boosting...
# Candidates sampling 1...
# Add features 1...
# Predict boosting...
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.0690301196137772, 'recall@5_users': 0.09263576871320776, 'users_hitted@5': 0.26583377872795294, 'recall@10': 0.136407893062271, 'recall@10_users': 0.15328708879610362, 'users_hitted@10': 0.3947309816497417, 'recall@20': 0.2565618810662607, 'recall@20_users': 0.2324583068713026, 'users_hitted@20': 0.5125601282736505}
# {'MAE': Timedelta('150 days 08:01:58.102347508')}
# Boosting metrics:
# ...

# %%
# %%time
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.06080365975351094, 'recall@5_users': 0.08472706968349131, 'users_hitted@5': 0.24398717263495456, 'recall@10': 0.12123636485171058, 'recall@10_users': 0.14305072336109304, 'users_hitted@10': 0.36912079102084444, 'recall@20': 0.23033400043872407, 'recall@20_users': 0.22126144204960144, 'users_hitted@20': 0.49309638339568856}
# {'MAE': Timedelta('151 days 20:42:27.378697646')}
# Boosting metrics:
# ...
