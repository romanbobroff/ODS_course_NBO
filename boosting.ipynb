# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import warnings

from lib.pipelines import boosting_pipeline

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# boosting_df_train2: Index(['user_id', 'item_id', 'tfidf_rnk', 'tfidf_score', 'target',
#        'user_id_le', 'ltv_turnover', 'ltv_quantity', 'ltv_check_count',
#        'ltv_purch_date_count', 'ltv_item_count', 'check_av_turn',
#        'check_av_quintity', 'check_av_item', 'frequence_client_per_month',
#        'ltv_quantity_cumul', 'monetary', 'frequency', 'elasticity_client',
#        'cluster_cart', 'category_id_le', 'uom_le', 'packing_size',
#        'price_uom'],
#       dtype='object')
# Fitting boosting...
# 20 features
# Index(['category_id_le', 'uom_le', 'packing_size', 'price_uom', 'ltv_turnover',
#        'ltv_quantity', 'ltv_check_count', 'ltv_purch_date_count',
#        'ltv_item_count', 'check_av_turn', 'check_av_quintity', 'check_av_item',
#        'frequence_client_per_month', 'ltv_quantity_cumul', 'monetary',
#        'frequency', 'elasticity_client', 'cluster_cart', 'tfidf_rnk',
#        'tfidf_score'],
#       dtype='object')
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# tfidf metrics:
# {'recall@1': 0.0036999607172954695, 'recall@1_users': 0.00685850416861041, 'users_hitted@1': 0.03868497491418009, 'recall@5': 0.012204498373293134, 'recall@5_users': 0.018568656168715857, 'users_hitted@5': 0.09409382976850629, 'recall@10': 0.020507586262468902, 'recall@10_users': 0.026685657311482744, 'users_hitted@10': 0.13427515183522576, 'recall@20': 0.033104911681064726, 'recall@20_users': 0.03721361153244575, 'users_hitted@20': 0.1843587712349265}
# {'MAE': Timedelta('78 days 07:14:48.171306661')}
# Boosting metrics:
# {'recall@1': 0.005684240920491135, 'recall@1_users': 0.0097562106885496, 'users_hitted@1': 0.059677845260100344, 'recall@5': 0.018137194006197937, 'recall@5_users': 0.02566415552999517, 'users_hitted@5': 0.13964439750022006, 'recall@10': 0.027074848660862676, 'recall@10_users': 0.03429475033749834, 'users_hitted@10': 0.17766921925886806, 'recall@20': 0.03997770622580504, 'recall@20_users': 0.044677654938293086, 'users_hitted@20': 0.21710236774931785}
# {'MAE': Timedelta('78 days 07:14:48.171306661')}
# CPU times: user 1h 41min 34s, sys: 4min 18s, total: 1h 45min 53s
# Wall time: 6min 39s

# %% [markdown]
# ## Таргет - item_id

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# tfidf metrics:
# {'recall@1': 0.003703318213409168, 'recall@1_users': 0.006983712078973833, 'users_hitted@1': 0.038861015755655315, 'recall@5': 0.012244788326657511, 'recall@5_users': 0.018679016767909295, 'users_hitted@5': 0.09422586039961271, 'recall@10': 0.020541161223605883, 'recall@10_users': 0.026707643211061866, 'users_hitted@10': 0.134451192676701, 'recall@20': 0.033175419099452395, 'recall@20_users': 0.03729350317623011, 'users_hitted@20': 0.18466684270750813}
# {'MAE': Timedelta('78 days 06:13:29.018595586')}
# Boosting metrics:
# {'recall@1': 0.0057950382922431765, 'recall@1_users': 0.01042898814213083, 'users_hitted@1': 0.0609541413607957, 'recall@5': 0.01759663713189252, 'recall@5_users': 0.025239444275198742, 'users_hitted@5': 0.13735586656104215, 'recall@10': 0.026692094103901075, 'recall@10_users': 0.033654608699843894, 'users_hitted@10': 0.17441246369157645, 'recall@20': 0.03941028938259004, 'recall@20_users': 0.0438724512227894, 'users_hitted@20': 0.21494586744124636}
# {'MAE': Timedelta('78 days 06:13:29.018595586')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# bm25 metrics:
# {'recall@1': 0.002924379115031174, 'recall@1_users': 0.006539832329996938, 'users_hitted@1': 0.03133526978258956, 'recall@5': 0.009343911684422225, 'recall@5_users': 0.01670276020492628, 'users_hitted@5': 0.07424522489217499, 'recall@10': 0.015189312418370876, 'recall@10_users': 0.024089110042406377, 'users_hitted@10': 0.10553648446439574, 'recall@20': 0.02409674960801233, 'recall@20_users': 0.03320416441038049, 'users_hitted@20': 0.1479183170495555}
# {'MAE': Timedelta('77 days 21:22:08.606436857')}
# Boosting metrics:
# {'recall@1': 0.004566194714629618, 'recall@1_users': 0.009061672857694568, 'users_hitted@1': 0.0474430067775724, 'recall@5': 0.013510564361521751, 'recall@5_users': 0.02177657267789749, 'users_hitted@5': 0.1076929847724672, 'recall@10': 0.020202054116122362, 'recall@10_users': 0.029633781431085155, 'users_hitted@10': 0.13907226476542559, 'recall@20': 0.028800601663303574, 'recall@20_users': 0.038236228687020334, 'users_hitted@20': 0.17141976938649767}
# {'MAE': Timedelta('77 days 21:22:08.606436857')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# cosine metrics:
# {'recall@1': 0.0034917959582461784, 'recall@1_users': 0.007197878884606339, 'users_hitted@1': 0.03736466860311592, 'recall@5': 0.01190232372306029, 'recall@5_users': 0.017878622032876285, 'users_hitted@5': 0.09413783997887509, 'recall@10': 0.018926205592917026, 'recall@10_users': 0.0246082056328666, 'users_hitted@10': 0.12758559985916731, 'recall@20': 0.030549857138540363, 'recall@20_users': 0.033958830244659975, 'users_hitted@20': 0.17384033095678197}
# {'MAE': Timedelta('76 days 23:23:08.518857266')}
# Boosting metrics:
# {'recall@1': 0.005835328245607556, 'recall@1_users': 0.01063009053836383, 'users_hitted@1': 0.06099815157116451, 'recall@5': 0.017539559697959648, 'recall@5_users': 0.02416906055575486, 'users_hitted@5': 0.134451192676701, 'recall@10': 0.02591651250163678, 'recall@10_users': 0.032136973353229445, 'users_hitted@10': 0.1692192588680574, 'recall@20': 0.037516661574464226, 'recall@20_users': 0.04122848381705072, 'users_hitted@20': 0.2055716926326908}
# {'MAE': Timedelta('76 days 23:23:08.518857266')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# markov metrics:
# {'recall@1': 0.00048347944037254776, 'recall@1_users': 0.000535708870908151, 'users_hitted@1': 0.0050611741924126395, 'recall@5': 0.0024375421785449284, 'recall@5_users': 0.0025018226771402036, 'users_hitted@5': 0.023633482968048587, 'recall@10': 0.0040155653519831054, 'recall@10_users': 0.004281734616768277, 'users_hitted@10': 0.03767274007569756, 'recall@20': 0.0061408603919540965, 'recall@20_users': 0.006389964512905145, 'users_hitted@20': 0.05320834433588593}
# {'MAE': Timedelta('78 days 15:02:22.033932336')}
# Boosting metrics:
# {'recall@1': 0.0016518880879395383, 'recall@1_users': 0.002097798976508838, 'users_hitted@1': 0.016503828888302086, 'recall@5': 0.004640059629130979, 'recall@5_users': 0.004718709044526438, 'users_hitted@5': 0.03930111785934337, 'recall@10': 0.0061341453997267, 'recall@10_users': 0.0062522503101840946, 'users_hitted@10': 0.049555496875275065, 'recall@20': 0.007453641372410112, 'recall@20_users': 0.0076249885231817575, 'users_hitted@20': 0.058577590000880204}
# {'MAE': Timedelta('78 days 15:02:22.033932336')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# toppop metrics:
# {'recall@1': 0.00396856040639133, 'recall@1_users': 0.004730452305995105, 'users_hitted@1': 0.037716750286066365, 'recall@5': 0.01065669266487824, 'recall@5_users': 0.012131605182939896, 'users_hitted@5': 0.0878883901065047, 'recall@10': 0.016508808391054286, 'recall@10_users': 0.017700378257942972, 'users_hitted@10': 0.13141448816125342, 'recall@20': 0.030892321742137584, 'recall@20_users': 0.028117394468921093, 'users_hitted@20': 0.20935657072440805}
# {'MAE': Timedelta('82 days 17:35:20.577189168')}
# Boosting metrics:
# {'recall@1': 0.0042203726149186984, 'recall@1_users': 0.005418325324614856, 'users_hitted@1': 0.042425842795528565, 'recall@5': 0.015011365124344868, 'recall@5_users': 0.01736024596409733, 'users_hitted@5': 0.1257811812340463, 'recall@10': 0.02455336907947529, 'recall@10_users': 0.025536436995255218, 'users_hitted@10': 0.17656896399964792, 'recall@20': 0.03762745894621627, 'recall@20_users': 0.03642307126638171, 'users_hitted@20': 0.23043746149106592}
# {'MAE': Timedelta('82 days 17:35:20.577189168')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# usertoppop metrics:
# {'recall@1': 0.013198317222947814, 'recall@1_users': 0.02225107275119123, 'users_hitted@1': 0.10892527066279377, 'recall@5': 0.06964454188644277, 'recall@5_users': 0.06728594277385949, 'users_hitted@5': 0.2969368893583311, 'recall@10': 0.0895242763756501, 'recall@10_users': 0.07470689119495301, 'users_hitted@10': 0.3090837074201215, 'recall@20': 0.09769642191639163, 'recall@20_users': 0.07594869798443386, 'users_hitted@20': 0.3094357891030719}
# {'MAE': Timedelta('69 days 09:10:20.210344331')}
# Boosting metrics:
# {'recall@1': 0.006298662709297914, 'recall@1_users': 0.010639947331828126, 'users_hitted@1': 0.06438693776956254, 'recall@5': 0.0182043439284719, 'recall@5_users': 0.025235002268426225, 'users_hitted@5': 0.14034856086612094, 'recall@10': 0.027115138614227055, 'recall@10_users': 0.033667412897402646, 'users_hitted@10': 0.1786814540973506, 'recall@20': 0.03851719541634631, 'recall@20_users': 0.04251401624582925, 'users_hitted@20': 0.21723439838042427}
# {'MAE': Timedelta('69 days 09:10:20.210344331')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.020367662069496365, 'recall@5_users': 0.014576911422382764, 'users_hitted@5': 0.09136519672564035, 'recall@10': 0.037069960594923776, 'recall@10_users': 0.02234542785992544, 'users_hitted@10': 0.11103776076049643, 'recall@20': 0.06044364946730729, 'recall@20_users': 0.02970140129670274, 'users_hitted@20': 0.12102807851421529}
# {'MAE': Timedelta('57 days 22:38:48.189784142')}
# Boosting metrics:
# {'recall@1': 0.005237693937369267, 'recall@1_users': 0.004589766091403559, 'users_hitted@1': 0.060778100519320484, 'recall@5': 0.024538224346628612, 'recall@5_users': 0.01646696176730577, 'users_hitted@5': 0.10355602499779949, 'recall@10': 0.04074570841970321, 'recall@10_users': 0.02358441333179468, 'users_hitted@10': 0.11755127189507966, 'recall@20': 0.062064038449048516, 'recall@20_users': 0.02988532498032792, 'users_hitted@20': 0.12226036440454185}
# {'MAE': Timedelta('57 days 22:38:48.189784142')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=2)
# Out:
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.030010495985452697, 'recall@5_users': 0.02347971746397827, 'users_hitted@5': 0.13638764193292843, 'recall@10': 0.05548741889539484, 'recall@10_users': 0.036176557664081024, 'users_hitted@10': 0.16578646245929055, 'recall@20': 0.08901377985071024, 'recall@20_users': 0.04768375968597327, 'users_hitted@20': 0.18233430155796146}
# {'MAE': Timedelta('62 days 00:14:05.171912833')}
# Boosting metrics:
# {'recall@1': 0.006547117421711585, 'recall@1_users': 0.0065056477909618445, 'users_hitted@1': 0.0767097966728281, 'recall@5': 0.03250568078154285, 'recall@5_users': 0.02458292572244571, 'users_hitted@5': 0.14109673444239063, 'recall@10': 0.056383197826662616, 'recall@10_users': 0.03608436820942376, 'users_hitted@10': 0.16961535076137663, 'recall@20': 0.08836821313969394, 'recall@20_users': 0.047366422421676185, 'users_hitted@20': 0.18638324091189157}
# {'MAE': Timedelta('62 days 00:14:05.171912833')}

# %% [markdown]
# ### 6 months

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# tfidf metrics:
# {'recall@1': 0.0026909281545408996, 'recall@1_users': 0.004272681476581786, 'users_hitted@1': 0.03721272047033672, 'recall@5': 0.00938119712569499, 'recall@5_users': 0.011592844967787461, 'users_hitted@5': 0.08988063424193836, 'recall@10': 0.016062617997697284, 'recall@10_users': 0.016970967723949168, 'users_hitted@10': 0.1292089791555318, 'recall@20': 0.02655425156694306, 'recall@20_users': 0.024281546936980865, 'users_hitted@20': 0.17553001959736325}
# {'MAE': Timedelta('138 days 19:12:28.548176322')}
# Boosting metrics:
# {'recall@1': 0.0043532647826851545, 'recall@1_users': 0.0057887236168985496, 'users_hitted@1': 0.05870301086762872, 'recall@5': 0.014027555192783491, 'recall@5_users': 0.015383433594967522, 'users_hitted@5': 0.13128006413682522, 'recall@10': 0.021863653004095564, 'recall@10_users': 0.02171067745782046, 'users_hitted@10': 0.16876002137894175, 'recall@20': 0.03259750328762184, 'recall@20_users': 0.028962058340494194, 'users_hitted@20': 0.20456974879743453}
# {'MAE': Timedelta('138 days 19:12:28.548176322')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# bm25 metrics:
# {'recall@1': 0.0020483349536414906, 'recall@1_users': 0.003746752804766051, 'users_hitted@1': 0.02834936753964012, 'recall@5': 0.006706859157063714, 'recall@5_users': 0.010041563152648548, 'users_hitted@5': 0.06741047568145377, 'recall@10': 0.010993763196110376, 'recall@10_users': 0.01441007932931331, 'users_hitted@10': 0.09558168537324069, 'recall@20': 0.01776477107202463, 'recall@20_users': 0.020587184604475617, 'users_hitted@20': 0.13424193835738465}
# {'MAE': Timedelta('142 days 04:45:00.025734138')}
# Boosting metrics:
# {'recall@1': 0.0031056828022814824, 'recall@1_users': 0.004934874442027538, 'users_hitted@1': 0.04151077854979512, 'recall@5': 0.00943981578257566, 'recall@5_users': 0.013047086644482916, 'users_hitted@5': 0.09411188312845181, 'recall@10': 0.014510882608950516, 'recall@10_users': 0.017910347451110083, 'users_hitted@10': 0.12355246748619277, 'recall@20': 0.02136926546398879, 'recall@20_users': 0.02371589197473153, 'users_hitted@20': 0.15550953144486016}
# {'MAE': Timedelta('142 days 04:45:00.025734138')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# cosine metrics:
# {'recall@1': 0.0024984819979892697, 'recall@1_users': 0.004252299013442336, 'users_hitted@1': 0.03538660252984144, 'recall@5': 0.008910035845861688, 'recall@5_users': 0.0110520370240936, 'users_hitted@5': 0.08760912168181008, 'recall@10': 0.014738721162109343, 'recall@10_users': 0.015590432828667997, 'users_hitted@10': 0.12181542846962409, 'recall@20': 0.0242183533908681, 'recall@20_users': 0.022140438990907264, 'users_hitted@20': 0.1642615357206485}
# {'MAE': Timedelta('138 days 00:28:15.212026320')}
# Boosting metrics:
# {'recall@1': 0.00430460023735026, 'recall@1_users': 0.00565352810407629, 'users_hitted@1': 0.05743363620167469, 'recall@5': 0.013537591702252615, 'recall@5_users': 0.014795463909972377, 'users_hitted@5': 0.1248663816141101, 'recall@10': 0.02060390488735817, 'recall@10_users': 0.02029114148576383, 'users_hitted@10': 0.1588054516301443, 'recall@20': 0.030305845607305877, 'recall@20_users': 0.026593312472815586, 'users_hitted@20': 0.1914306075182612}
# {'MAE': Timedelta('138 days 00:28:15.212026320')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# markov metrics:
# {'recall@1': 0.00048332741616702557, 'recall@1_users': 0.000496456696043045, 'users_hitted@1': 0.006458221984678425, 'recall@5': 0.0019664900364873487, 'recall@5_users': 0.002011732110616631, 'users_hitted@5': 0.025654730090860504, 'recall@10': 0.0032782207357415646, 'recall@10_users': 0.003173979428076926, 'users_hitted@10': 0.039818278995189735, 'recall@20': 0.004709400773545068, 'recall@20_users': 0.004557072133553387, 'users_hitted@20': 0.05315784785319793}
# {'MAE': Timedelta('141 days 08:51:54.497598724')}
# Boosting metrics:
# {'recall@1': 0.0014101658023179808, 'recall@1_users': 0.001561865986522055, 'users_hitted@1': 0.01797167290219134, 'recall@5': 0.003579056106902734, 'recall@5_users': 0.0035638381684478916, 'users_hitted@5': 0.04053091038660253, 'recall@10': 0.004598799534147579, 'recall@10_users': 0.004435833114004235, 'users_hitted@10': 0.04874844111883128, 'recall@20': 0.005439368953568494, 'recall@20_users': 0.005262499680355103, 'users_hitted@20': 0.0562310707286656}
# {'MAE': Timedelta('141 days 08:51:54.497598724')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# toppop metrics:
# {'recall@1': 0.0036996114578459966, 'recall@1_users': 0.004301904297939997, 'users_hitted@1': 0.04623196151790487, 'recall@5': 0.011850922801440913, 'recall@5_users': 0.013929633360564657, 'users_hitted@5': 0.12758328879387137, 'recall@10': 0.016683090950717194, 'recall@10_users': 0.02005287407265937, 'users_hitted@10': 0.16455104222340994, 'recall@20': 0.027039791007898033, 'recall@20_users': 0.02734711197228071, 'users_hitted@20': 0.22969000534473544}
# {'MAE': Timedelta('144 days 11:32:17.294155012')}
# Boosting metrics:
# {'recall@1': 0.004146440465011851, 'recall@1_users': 0.005724624837027098, 'users_hitted@1': 0.057144129698913235, 'recall@5': 0.015431084920737621, 'recall@5_users': 0.01862142649692765, 'users_hitted@5': 0.17172189559950116, 'recall@10': 0.024699468782247175, 'recall@10_users': 0.028001583900797322, 'users_hitted@10': 0.23443345804382684, 'recall@20': 0.03799816180740121, 'recall@20_users': 0.03897964371019667, 'users_hitted@20': 0.29509620523784075}
# {'MAE': Timedelta('144 days 11:32:17.294155014')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# usertoppop metrics:
# {'recall@1': 0.009511706588184028, 'recall@1_users': 0.013556174557401511, 'users_hitted@1': 0.10330928202387316, 'recall@5': 0.055541730400630866, 'recall@5_users': 0.04014416866762768, 'users_hitted@5': 0.2466818100837342, 'recall@10': 0.07186979137288213, 'recall@10_users': 0.043657629175434455, 'users_hitted@10': 0.2500890789239266, 'recall@20': 0.07809885317574869, 'recall@20_users': 0.04413953807342325, 'users_hitted@20': 0.25011134865490825}
# {'MAE': Timedelta('123 days 10:49:42.331158526')}
# Boosting metrics:
# {'recall@1': 0.004692810587635445, 'recall@1_users': 0.005857568156272068, 'users_hitted@1': 0.059794227685729555, 'recall@5': 0.014545168993163738, 'recall@5_users': 0.015449698390684113, 'users_hitted@5': 0.133328879387137, 'recall@10': 0.021536273335478997, 'recall@10_users': 0.020720962155176808, 'users_hitted@10': 0.1671343310172813, 'recall@20': 0.030583454718193574, 'recall@20_users': 0.026048281337063058, 'users_hitted@20': 0.19615179048637094}
# {'MAE': Timedelta('123 days 10:49:42.331158526')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.018060636387784545, 'recall@5_users': 0.01516339858351044, 'users_hitted@5': 0.11535720648494566, 'recall@10': 0.0334315306206105, 'recall@10_users': 0.0231941857998457, 'users_hitted@10': 0.13916354890432925, 'recall@20': 0.057563576173176555, 'recall@20_users': 0.031911689570846384, 'users_hitted@20': 0.15165686798503475}
# {'MAE': Timedelta('115 days 16:31:17.596682418')}
# Boosting metrics:
# {'recall@1': 0.004520272654175363, 'recall@1_users': 0.004700341609669996, 'users_hitted@1': 0.07656333511491181, 'recall@5': 0.02314394130153468, 'recall@5_users': 0.016989190404278754, 'users_hitted@5': 0.12998841973988953, 'recall@10': 0.0399882196515269, 'recall@10_users': 0.02503822351542128, 'users_hitted@10': 0.14642348120434706, 'recall@20': 0.06505055660106536, 'recall@20_users': 0.03301807447094735, 'users_hitted@20': 0.15270354534117228}
# {'MAE': Timedelta('115 days 16:31:17.596682418')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='item_id', model_names=model_names, test_months_global=6)
# Out:
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.026898297006249045, 'recall@5_users': 0.02415094867326761, 'users_hitted@5': 0.17319169784429003, 'recall@10': 0.04926570137616425, 'recall@10_users': 0.03702007117103575, 'users_hitted@10': 0.20750935328701228, 'recall@20': 0.08079692331922265, 'recall@20_users': 0.049919405071998574, 'users_hitted@20': 0.22790842686620347}
# {'MAE': Timedelta('122 days 11:05:09.960735040')}
# Boosting metrics:
# {'recall@1': 0.005388492383445649, 'recall@1_users': 0.00608193124618382, 'users_hitted@1': 0.09246392303580973, 'recall@5': 0.030367941759932224, 'recall@5_users': 0.0252320700469132, 'users_hitted@5': 0.17726705861393194, 'recall@10': 0.05388787066051071, 'recall@10_users': 0.03770251176738472, 'users_hitted@10': 0.2106048458934616, 'recall@20': 0.08724728751596658, 'recall@20_users': 0.05073381523331182, 'users_hitted@20': 0.23176109032602887}
# {'MAE': Timedelta('122 days 11:05:09.960735042')}

# %% [markdown]
# ## Таргет - category_id

# %% [markdown]
# ### 2 months

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# tfidf metrics:
# {'recall@1': 0.03214131029643333, 'recall@1_users': 0.029010171342379557, 'users_hitted@1': 0.15381568523897543, 'recall@5': 0.09731030986331633, 'recall@5_users': 0.08206006204682455, 'users_hitted@5': 0.324575301469941, 'recall@10': 0.15287687054502233, 'recall@10_users': 0.12432455219267047, 'users_hitted@10': 0.4166886717718511, 'recall@20': 0.2307539929022532, 'recall@20_users': 0.1821380719761652, 'users_hitted@20': 0.49441070328316167}
# {'MAE': Timedelta('85 days 16:06:00.177666114')}
# Boosting metrics:
# {'recall@1': 0.03040212730953764, 'recall@1_users': 0.02810314778571995, 'users_hitted@1': 0.15139512366869112, 'recall@5': 0.09500035253709194, 'recall@5_users': 0.08024542560406728, 'users_hitted@5': 0.3236510870521961, 'recall@10': 0.15006328880174322, 'recall@10_users': 0.1224274954853901, 'users_hitted@10': 0.41334389578382186, 'recall@20': 0.2271681870528235, 'recall@20_users': 0.17913389255868822, 'users_hitted@20': 0.49168207024029575}
# {'MAE': Timedelta('85 days 16:06:00.177666114')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# bm25 metrics:
# {'recall@1': 0.03438076020427006, 'recall@1_users': 0.031513196142105425, 'users_hitted@1': 0.15491594049819557, 'recall@5': 0.10148032003652956, 'recall@5_users': 0.08942740459100194, 'users_hitted@5': 0.3376463339494763, 'recall@10': 0.15630823157322196, 'recall@10_users': 0.13269096317783155, 'users_hitted@10': 0.4247865504797113, 'recall@20': 0.2396144251463029, 'recall@20_users': 0.19370235836706162, 'users_hitted@20': 0.5074377255523281}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}
# Boosting metrics:
# {'recall@1': 0.0329672543404031, 'recall@1_users': 0.03023375181290584, 'users_hitted@1': 0.1526714197693865, 'recall@5': 0.09990565435920508, 'recall@5_users': 0.08835566471934035, 'users_hitted@5': 0.3369861807939442, 'recall@10': 0.15349464982994282, 'recall@10_users': 0.13026585597097692, 'users_hitted@10': 0.4218378663850013, 'recall@20': 0.23546120245365815, 'recall@20_users': 0.19016054031527863, 'users_hitted@20': 0.5055012762961006}
# {'MAE': Timedelta('85 days 15:10:16.457711889')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# cosine metrics:
# {'recall@1': 0.0285588619431173, 'recall@1_users': 0.026000876362821904, 'users_hitted@1': 0.15139512366869112, 'recall@5': 0.08535762369855057, 'recall@5_users': 0.07194845340223417, 'users_hitted@5': 0.31106416688671773, 'recall@10': 0.13215776202739046, 'recall@10_users': 0.10853600216852692, 'users_hitted@10': 0.395871842267406, 'recall@20': 0.2085575860945941, 'recall@20_users': 0.16707721684767365, 'users_hitted@20': 0.4812956605932576}
# {'MAE': Timedelta('85 days 16:49:30.090817356')}
# Boosting metrics:
# {'recall@1': 0.0276019755507133, 'recall@1_users': 0.025332156218025034, 'users_hitted@1': 0.14884253146730042, 'recall@5': 0.08334984102255902, 'recall@5_users': 0.07056971199476034, 'users_hitted@5': 0.30749933984684447, 'recall@10': 0.12872304350307714, 'recall@10_users': 0.1057154157652514, 'users_hitted@10': 0.39045858639204295, 'recall@20': 0.20460917066488496, 'recall@20_users': 0.16304654851502176, 'users_hitted@20': 0.4770706803978523}
# {'MAE': Timedelta('85 days 16:49:30.090817356')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# markov metrics:
# {'recall@1': 0.011670656491215112, 'recall@1_users': 0.014248590167349168, 'users_hitted@1': 0.08709620631986621, 'recall@5': 0.03767446389180804, 'recall@5_users': 0.038979464121862165, 'users_hitted@5': 0.21459378575829594, 'recall@10': 0.06587071625464594, 'recall@10_users': 0.06265008719557559, 'users_hitted@10': 0.29838922630050174, 'recall@20': 0.11121705876625448, 'recall@20_users': 0.10024013638128591, 'users_hitted@20': 0.38909426987060997}
# {'MAE': Timedelta('86 days 21:22:53.677803328')}
# Boosting metrics:
# {'recall@1': 0.010277295604030338, 'recall@1_users': 0.012654445775296052, 'users_hitted@1': 0.0767978170935657, 'recall@5': 0.03492131707857548, 'recall@5_users': 0.036182103175438116, 'users_hitted@5': 0.20222691664466155, 'recall@10': 0.06123737161774235, 'recall@10_users': 0.05980002492338544, 'users_hitted@10': 0.2872106328668251, 'recall@20': 0.10532465308671406, 'recall@20_users': 0.0962654931054067, 'users_hitted@20': 0.3799401461138984}
# {'MAE': Timedelta('86 days 21:22:53.677803328')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# toppop metrics:
# {'recall@1': 0.020809760912701744, 'recall@1_users': 0.0109727458346157, 'users_hitted@1': 0.031379279992958364, 'recall@5': 0.10993113775470804, 'recall@5_users': 0.06332079881224069, 'users_hitted@5': 0.2720271102895872, 'recall@10': 0.16953005126896564, 'recall@10_users': 0.11906548347031141, 'users_hitted@10': 0.42588680573893145, 'recall@20': 0.2609479554527416, 'recall@20_users': 0.18539419213445277, 'users_hitted@20': 0.5270662793768154}
# {'MAE': Timedelta('85 days 05:25:34.753804834')}
# Boosting metrics:
# {'recall@1': 0.036344895430783536, 'recall@1_users': 0.02558552351764527, 'users_hitted@1': 0.13414312120411936, 'recall@5': 0.12294815018751616, 'recall@5_users': 0.08735914723620379, 'users_hitted@5': 0.34618431476102457, 'recall@10': 0.18942657323874149, 'recall@10_users': 0.14105919941414188, 'users_hitted@10': 0.4723175776780213, 'recall@20': 0.2768389845588754, 'recall@20_users': 0.21338966731324555, 'users_hitted@20': 0.5845436141184754}
# {'MAE': Timedelta('85 days 05:25:34.753804834')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# usertoppop metrics:
# {'recall@1': 0.042119788746344526, 'recall@1_users': 0.03982316796587005, 'users_hitted@1': 0.1542557873426635, 'recall@5': 0.16105237358187757, 'recall@5_users': 0.14560823501735157, 'users_hitted@5': 0.4199894375495115, 'recall@10': 0.2779033108269177, 'recall@10_users': 0.22734643232134008, 'users_hitted@10': 0.4983276120059854, 'recall@20': 0.3561732602294513, 'recall@20_users': 0.26492564586507394, 'users_hitted@20': 0.5103864096470381}
# {'MAE': Timedelta('81 days 17:03:33.114372776')}
# Boosting metrics:
# {'recall@1': 0.03308812420049624, 'recall@1_users': 0.027179355722008375, 'users_hitted@1': 0.1108177097086524, 'recall@5': 0.09728009239829305, 'recall@5_users': 0.08431581046946832, 'users_hitted@5': 0.2989613590352962, 'recall@10': 0.14545008914152183, 'recall@10_users': 0.12219066259385396, 'users_hitted@10': 0.3836370037848781, 'recall@20': 0.2083460638394311, 'recall@20_users': 0.16799727727515026, 'users_hitted@20': 0.4505325235454625}
# {'MAE': Timedelta('81 days 17:03:33.114372776')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Add features...
# Fit boosting...
# Candidates sampling 1...
# Add features 1...
# Predict boosting...
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.09267462991586205, 'recall@5_users': 0.09205122974127876, 'users_hitted@5': 0.23435437021388963, 'recall@10': 0.18093963357728768, 'recall@10_users': 0.15374335151726662, 'users_hitted@10': 0.3527858463163454, 'recall@20': 0.3130510679460523, 'recall@20_users': 0.22998387822368901, 'users_hitted@20': 0.46021476982659976}
# {'MAE': Timedelta('85 days 22:52:51.514434022')}
# Boosting metrics:
# {'recall@1': 0.00927676176214826, 'recall@1_users': 0.009958157112690191, 'users_hitted@1': 0.0672476014435349, 'recall@5': 0.083005707241202, 'recall@5_users': 0.06743234974318293, 'users_hitted@5': 0.21793856174632514, 'recall@10': 0.15603164416508225, 'recall@10_users': 0.11352270842491098, 'users_hitted@10': 0.298785318193821, 'recall@20': 0.2656308045160144, 'recall@20_users': 0.17818136103964957, 'users_hitted@20': 0.3908546782853622}
# {'MAE': Timedelta('85 days 22:52:51.514434022')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=2)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Add features...
# Fit boosting...
# Candidates sampling 1...
# Add features 1...
# Predict boosting...
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.08060361649538181, 'recall@5_users': 0.08218394308923717, 'users_hitted@5': 0.21063286682510343, 'recall@10': 0.1577072326897003, 'recall@10_users': 0.142458662712969, 'users_hitted@10': 0.3266877915676437, 'recall@20': 0.2820877932410105, 'recall@20_users': 0.2207509707569567, 'users_hitted@20': 0.44349088988645363}
# {'MAE': Timedelta('88 days 01:06:22.992523198')}
# Boosting metrics:
# {'recall@1': 0.00860526253940861, 'recall@1_users': 0.008879246405356932, 'users_hitted@1': 0.0593257635771499, 'recall@5': 0.0712835152244647, 'recall@5_users': 0.05670111819693524, 'users_hitted@5': 0.1891118739547575, 'recall@10': 0.1355511374568243, 'recall@10_users': 0.10103706001984093, 'users_hitted@10': 0.27119091629257985, 'recall@20': 0.239643395724297, 'recall@20_users': 0.16491160167092558, 'users_hitted@20': 0.371886277616407}
# {'MAE': Timedelta('88 days 01:06:22.992523198')}

# %% [markdown]
# ### 6 months

# %%
model_names = [
    'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# tfidf metrics:
# {'recall@1': 0.02971191695174136, 'recall@1_users': 0.02270874532856474, 'users_hitted@1': 0.1629698913237128, 'recall@5': 0.08916450717746743, 'recall@5_users': 0.06414666749790826, 'users_hitted@5': 0.30558524853019775, 'recall@10': 0.14038283513005045, 'recall@10_users': 0.09652422327493951, 'users_hitted@10': 0.36961072510244075, 'recall@20': 0.21452216393536905, 'recall@20_users': 0.14301528918166162, 'users_hitted@20': 0.42579725636914306}
# {'MAE': Timedelta('149 days 13:42:23.159909754')}
# Boosting metrics:
# {'recall@1': 0.028478713132459362, 'recall@1_users': 0.021737645727127244, 'users_hitted@1': 0.16096561553536434, 'recall@5': 0.08773664517684585, 'recall@5_users': 0.06343205998477598, 'users_hitted@5': 0.3052066631035097, 'recall@10': 0.1375978959220217, 'recall@10_users': 0.09529907680922918, 'users_hitted@10': 0.36831908070550506, 'recall@20': 0.21104043691913613, 'recall@20_users': 0.14069175680172394, 'users_hitted@20': 0.4248173882059505}
# {'MAE': Timedelta('149 days 13:42:23.159909756')}

# %%
model_names = [
    # 'tfidf',
    'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# bm25 metrics:
# {'recall@1': 0.03130125676188327, 'recall@1_users': 0.024359796240001102, 'users_hitted@1': 0.16101015499732763, 'recall@5': 0.09218060297583695, 'recall@5_users': 0.0687857276842745, 'users_hitted@5': 0.31128629966150007, 'recall@10': 0.1418394534529154, 'recall@10_users': 0.10258838373619106, 'users_hitted@10': 0.3760912168181008, 'recall@20': 0.21886547460650843, 'recall@20_users': 0.15135924024345607, 'users_hitted@20': 0.43474968822376625}
# {'MAE': Timedelta('149 days 18:01:29.407337722')}
# Boosting metrics:
# {'recall@1': 0.03035893420221667, 'recall@1_users': 0.023713425486735225, 'users_hitted@1': 0.1613887404240157, 'recall@5': 0.09093523302022122, 'recall@5_users': 0.06798215428125401, 'users_hitted@5': 0.3114421877783716, 'recall@10': 0.1386640918698135, 'recall@10_users': 0.10059240490066251, 'users_hitted@10': 0.37488865134509175, 'recall@20': 0.21516918118584435, 'recall@20_users': 0.14959090168452674, 'users_hitted@20': 0.43432656333511493}
# {'MAE': Timedelta('149 days 18:01:29.407337724')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# cosine metrics:
# {'recall@1': 0.027033154933534184, 'recall@1_users': 0.020795069332024293, 'users_hitted@1': 0.16236860858720828, 'recall@5': 0.0789526947438973, 'recall@5_users': 0.05702166296361622, 'users_hitted@5': 0.2966996258685195, 'recall@10': 0.12301622851985679, 'recall@10_users': 0.08584954140268698, 'users_hitted@10': 0.3597006948156066, 'recall@20': 0.19559276181248886, 'recall@20_users': 0.13289216574900503, 'users_hitted@20': 0.42051933012649206}
# {'MAE': Timedelta('149 days 14:37:40.007695268')}
# Boosting metrics:
# {'recall@1': 0.026510011071184062, 'recall@1_users': 0.02040735850699432, 'users_hitted@1': 0.1618564047746303, 'recall@5': 0.07717201478959773, 'recall@5_users': 0.05594903788537409, 'users_hitted@5': 0.2949180473899875, 'recall@10': 0.11992492387869698, 'recall@10_users': 0.08415379471938009, 'users_hitted@10': 0.35729556386958844, 'recall@20': 0.19232007113871719, 'recall@20_users': 0.13107482393351505, 'users_hitted@20': 0.42027436308569394}
# {'MAE': Timedelta('149 days 14:37:40.007695268')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# markov metrics:
# {'recall@1': 0.008281820806083954, 'recall@1_users': 0.007431510414552196, 'users_hitted@1': 0.07972563691430608, 'recall@5': 0.031294620687519425, 'recall@5_users': 0.026120424182804743, 'users_hitted@5': 0.20521557099590237, 'recall@10': 0.05505619095967589, 'recall@10_users': 0.044897082033148045, 'users_hitted@10': 0.27748084803135575, 'recall@20': 0.09442249009842404, 'recall@20_users': 0.07486043974896055, 'users_hitted@20': 0.35054783538214856}
# {'MAE': Timedelta('150 days 06:21:13.340956180')}
# Boosting metrics:
# {'recall@1': 0.006290998496929157, 'recall@1_users': 0.005542318625591737, 'users_hitted@1': 0.06168715481916978, 'recall@5': 0.02733067226751343, 'recall@5_users': 0.022734133753426228, 'users_hitted@5': 0.18690985212898628, 'recall@10': 0.04951285684107376, 'recall@10_users': 0.04045282781413394, 'users_hitted@10': 0.26198111526812756, 'recall@20': 0.08711174817425003, 'recall@20_users': 0.06989248512363501, 'users_hitted@20': 0.3402592196686264}
# {'MAE': Timedelta('150 days 06:21:13.340956180')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    'toppop',
    # 'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# toppop metrics:
# {'recall@1': 0.019087561895218597, 'recall@1_users': 0.010691564815232505, 'users_hitted@1': 0.04471761981115268, 'recall@5': 0.1116707533824624, 'recall@5_users': 0.061174867340685675, 'users_hitted@5': 0.31148672724033494, 'recall@10': 0.17303674504976502, 'recall@10_users': 0.11367450140927662, 'users_hitted@10': 0.45721984678425087, 'recall@20': 0.26982499565890133, 'recall@20_users': 0.1833428650695144, 'users_hitted@20': 0.5562978799216105}
# {'MAE': Timedelta('149 days 08:38:03.431032420')}
# Boosting metrics:
# {'recall@1': 0.035291749479344665, 'recall@1_users': 0.02659320238556184, 'users_hitted@1': 0.1798503474078033, 'recall@5': 0.11851144003919709, 'recall@5_users': 0.08759566653248535, 'users_hitted@5': 0.39328344913593444, 'recall@10': 0.18502038933848292, 'recall@10_users': 0.14138454248733934, 'users_hitted@10': 0.5184170675218244, 'recall@20': 0.2803874140213615, 'recall@20_users': 0.21130611012906564, 'users_hitted@20': 0.6128407268840192}
# {'MAE': Timedelta('149 days 08:38:03.431032420')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    'usertoppop',
    # 'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# usertoppop metrics:
# {'recall@1': 0.035667793693296125, 'recall@1_users': 0.029663101249031536, 'users_hitted@1': 0.15366114377338322, 'recall@5': 0.143221968945384, 'recall@5_users': 0.10778305707510778, 'users_hitted@5': 0.36217263495456975, 'recall@10': 0.24617181460135443, 'recall@10_users': 0.15838158506963168, 'users_hitted@10': 0.3932166399429895, 'recall@20': 0.31560174263312796, 'recall@20_users': 0.17724357162143448, 'users_hitted@20': 0.3955549616960627}
# {'MAE': Timedelta('139 days 18:21:13.076687678')}
# Boosting metrics:
# {'recall@1': 0.027607175366007153, 'recall@1_users': 0.019673441517327073, 'users_hitted@1': 0.10885444503830394, 'recall@5': 0.08583762189639096, 'recall@5_users': 0.061309919097083575, 'users_hitted@5': 0.2721583823267415, 'recall@10': 0.12866131577870463, 'recall@10_users': 0.08857968553253731, 'users_hitted@10': 0.332464813825049, 'recall@20': 0.18401170603517783, 'recall@20_users': 0.11941286138642375, 'users_hitted@20': 0.37179315873864244}
# {'MAE': Timedelta('139 days 18:21:13.076687678')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    'apriori',
    # 'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Add features...
# Fit boosting...
# Candidates sampling 1...
# Add features 1...
# Predict boosting...
# apriori metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.0690301196137772, 'recall@5_users': 0.09263576871320776, 'users_hitted@5': 0.26583377872795294, 'recall@10': 0.136407893062271, 'recall@10_users': 0.15328708879610362, 'users_hitted@10': 0.3947309816497417, 'recall@20': 0.2565618810662607, 'recall@20_users': 0.2324583068713026, 'users_hitted@20': 0.5125601282736505}
# {'MAE': Timedelta('150 days 08:01:58.102347508')}
# Boosting metrics:
# {'recall@1': 0.006736721491701036, 'recall@1_users': 0.008025468612940631, 'users_hitted@1': 0.06578478531979334, 'recall@5': 0.07425011497744755, 'recall@5_users': 0.06981782927816291, 'users_hitted@5': 0.256101906288972, 'recall@10': 0.14413984342744623, 'recall@10_users': 0.12436506812340245, 'users_hitted@10': 0.3550463210404418, 'recall@20': 0.257482598761812, 'recall@20_users': 0.19757782614698735, 'users_hitted@20': 0.4576652414038838}
# {'MAE': Timedelta('150 days 08:01:58.102347508')}

# %%
model_names = [
    # 'tfidf',
    # 'bm25',
    # 'cosine',
    # 'markov',
    # 'toppop',
    # 'usertoppop',
    # 'apriori',
    'apriori_lastnext',
]
predicted_item = boosting_pipeline(k_top=50, target='category_id', model_names=model_names, test_months_global=6)
# Out:
# Candidates generation...
# Candidates sampling...
# Pos and neg candidates generation...
# Adding features...
# Fitting boosting...
# Candidates sampling 1...
# Add features 1...
# Predicting boosting...
# apriori_lastnext metrics:
# {'recall@1': 0.0, 'recall@1_users': 0.0, 'users_hitted@1': 0.0, 'recall@5': 0.06080365975351094, 'recall@5_users': 0.08472706968349131, 'users_hitted@5': 0.24398717263495456, 'recall@10': 0.12123636485171058, 'recall@10_users': 0.14305072336109304, 'users_hitted@10': 0.36912079102084444, 'recall@20': 0.23033400043872407, 'recall@20_users': 0.22126144204960144, 'users_hitted@20': 0.49309638339568856}
# {'MAE': Timedelta('151 days 20:42:27.378697646')}
# Boosting metrics:
# {'recall@1': 0.004336674596775531, 'recall@1_users': 0.00533506845236856, 'users_hitted@1': 0.04396044895777659, 'recall@5': 0.057919949198447826, 'recall@5_users': 0.0585211344693403, 'users_hitted@5': 0.21013718154284697, 'recall@10': 0.11560213481117551, 'recall@10_users': 0.10139915285019303, 'users_hitted@10': 0.3012649207197577, 'recall@20': 0.2124927368884645, 'recall@20_users': 0.17118582340323685, 'users_hitted@20': 0.4139497594869054}
# {'MAE': Timedelta('151 days 20:42:27.378697646')}
